# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

def get_participant_centroids(features, segment_info, participant_id='P1'):
    """
    Calculate initial centroids from a participant's data
    
    Args:
        features: Feature matrix (n_samples, n_features)
        segment_info: DataFrame containing segment information
        participant_id: ID of the participant to use for seeding
        
    Returns:
        initial_centroids: Array of shape (n_clusters, n_features)
    """
    # Create a mask for the participant's data
    participant_mask = segment_info['participant_id'] == participant_id
    
    # Get the participant's features and labels
    participant_features = features[participant_mask]
    participant_labels = segment_info.loc[participant_mask, 'instrument_label']
    
    # Print some information about the seed participant's data
    print(f"\nSeed Participant ({participant_id}) Data:")
    print("Number of examples per instrument:")
    print(participant_labels.value_counts())
    
    # Calculate mean feature vector for each instrument type
    centroids = []
    for instrument in ['hhc', 'hho', 'kd', 'sd']:
        instrument_mask = participant_labels == instrument
        if not any(instrument_mask):
            raise ValueError(f"No samples found for instrument {instrument} from participant {participant_id}")
        
        centroid = participant_features[instrument_mask].mean(axis=0)
        centroids.append(centroid)
        print(f"\nCentroid shape for {instrument}: {centroid.shape}")
    
    return np.array(centroids)

def seeded_kmeans(features_path, segment_info_path, seed_participant='P1', output_dir=''):
    """
    Perform k-means clustering with seeds from a specific participant's data
    
    Args:
        features_path: Path to the features .npy file
        segment_info_path: Path to the segment info CSV file
        seed_participant: Participant ID to use for seeding
        output_dir: Directory to save cluster assignments
    """
    # Load data
    print(f"Loading features from: {features_path}")
    print(f"Loading segment info from: {segment_info_path}")
    
    X = np.load(features_path)
    segment_info = pd.read_csv(segment_info_path)
    
    print(f"\nFeature matrix shape: {X.shape}")
    print(f"Number of segments: {len(segment_info)}")
    
    # Standardize features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Get initial centroids from the seed participant
    print(f"\nGetting centroids from participant {seed_participant}")
    initial_centroids = get_participant_centroids(X_scaled, segment_info, seed_participant)
    print(f"Initial centroids shape: {initial_centroids.shape}")
    
    # Perform k-means clustering with the seeded centroids
    print("\nPerforming seeded k-means clustering...")
    kmeans = KMeans(
        n_clusters=4,
        init=initial_centroids,
        n_init=1,  # Since we're providing our own centroids
        random_state=42
    )
    
    cluster_labels = kmeans.fit_predict(X_scaled)
    
    # Save cluster assignments
    if output_dir:
        os.makedirs(os.path.dirname(output_dir), exist_ok=True)
        np.save(output_dir, cluster_labels)
        print(f"\nSaved cluster assignments to: {output_dir}")
    
    # Print cluster sizes
    print("\nCluster sizes:")
    for i in range(4):
        print(f"Cluster {i}: {np.sum(cluster_labels == i)} sounds")
    
    # Calculate clustering metrics
    silhouette = silhouette_score(X_scaled, cluster_labels)
    davies_bouldin = davies_bouldin_score(X_scaled, cluster_labels)
    calinski_harabasz = calinski_harabasz_score(X_scaled, cluster_labels)
    
    print("\nClustering Metrics:")
    print(f"Silhouette Score: {silhouette:.3f}")
    print(f"Davies-Bouldin Index: {davies_bouldin:.3f}")
    print(f"Calinski-Harabasz Index: {calinski_harabasz:.3f}")
    
    # Create confusion matrix between true labels and clusters
    true_labels = segment_info['instrument_label']
    confusion_matrix = pd.crosstab(
        true_labels, 
        cluster_labels,
        normalize='index'
    )
    
    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap='YlOrRd')
    plt.title(f'Normalized Confusion Matrix\nSeeded with Participant {seed_participant}')
    plt.xlabel('Cluster')
    plt.ylabel('True Label')
    
    # Save visualization
    if output_dir:
        viz_dir = str(Path(output_dir).parent.parent / 'visualization' / 'clustering_eval')
        os.makedirs(viz_dir, exist_ok=True)
        viz_path = f"{viz_dir}/seeded_kmeans_{seed_participant}_confusion.png"
        plt.savefig(viz_path, dpi=300, bbox_inches='tight')
        print(f"\nSaved confusion matrix visualization to: {viz_path}")
    plt.close()
    
    return cluster_labels, kmeans

def evaluate_all_participants(features_path, segment_info_path, base_output_dir):
    """
    Run seeded k-means with each participant as the seed and compare results
    """
    # Load segment info to get unique participants
    segment_info = pd.read_csv(segment_info_path)
    participants = segment_info['participant_id'].unique()
    
    # Store results
    results = []
    
    for participant in participants:
        print(f"\n{'='*50}")
        print(f"Evaluating with seed participant: {participant}")
        print('='*50)
        
        output_dir = f"{base_output_dir}/seeded_kmeans_{participant}_cluster.npy"
        
        try:
            cluster_labels, kmeans = seeded_kmeans(
                features_path=features_path,
                segment_info_path=segment_info_path,
                seed_participant=participant,
                output_dir=output_dir
            )
            
            # Calculate metrics
            X = np.load(features_path)
            X_scaled = StandardScaler().fit_transform(X)
            
            metrics = {
                'participant': participant,
                'silhouette': silhouette_score(X_scaled, cluster_labels),
                'davies_bouldin': davies_bouldin_score(X_scaled, cluster_labels),
                'calinski_harabasz': calinski_harabasz_score(X_scaled, cluster_labels)
            }
            
            results.append(metrics)
            
        except Exception as e:
            print(f"Error processing participant {participant}: {str(e)}")
            continue
    
    # Convert results to DataFrame and sort by silhouette score
    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values('silhouette', ascending=False)
    
    print("\nResults for all participants:")
    print(results_df)
    
    # Save results
    results_path = Path(base_output_dir).parent / 'results' / 'seeded_kmeans_comparison.csv'
    os.makedirs(results_path.parent, exist_ok=True)
    results_df.to_csv(results_path, index=False)
    print(f"\nSaved comparison results to: {results_path}")
    
    return results_df

if __name__ == "__main__":
    # Paths
    features_path = '../../../extracted_features/features/mfcc_extracted_features.npy'
    segment_info_path = '../../../segment_info/segment_info_base_names.csv'
    base_output_dir = '../../../cluster_assignments/seeded_kmeans'
    
    # Evaluate using all participants as seeds
    results_df = evaluate_all_participants(
        features_path=features_path,
        segment_info_path=segment_info_path,
        base_output_dir=base_output_dir
    )
# Out:
# ==================================================
# Evaluating with seed participant: P1
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P1
#
# Seed Participant (P1) Data:
# Number of examples per instrument:
# instrument_label
# kd     38
# hhc    32
# hho    31
# sd     27
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P1_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1348 sounds
# Cluster 1: 910 sounds
# Cluster 2: 1357 sounds
# Cluster 3: 2099 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.124
# Davies-Bouldin Index: 2.139
# Calinski-Harabasz Index: 752.866
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P1_confusion.png
#
# ==================================================
# Evaluating with seed participant: P10
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P10
#
# Seed Participant (P10) Data:
# Number of examples per instrument:
# instrument_label
# kd     52
# sd     45
# hhc    37
# hho    34
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P10_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1967 sounds
# Cluster 1: 1628 sounds
# Cluster 2: 1475 sounds
# Cluster 3: 644 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.133
# Davies-Bouldin Index: 2.223
# Calinski-Harabasz Index: 787.233
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P10_confusion.png
#
# ==================================================
# Evaluating with seed participant: P11
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P11
#
# Seed Participant (P11) Data:
# Number of examples per instrument:
# instrument_label
# kd     58
# hhc    49
# sd     48
# hho    38
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P11_cluster.npy
#
# Cluster sizes:
# Cluster 0: 2084 sounds
# Cluster 1: 1365 sounds
# Cluster 2: 1350 sounds
# Cluster 3: 915 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.124
# Davies-Bouldin Index: 2.141
# Calinski-Harabasz Index: 752.861
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P11_confusion.png
#
# ==================================================
# Evaluating with seed participant: P12
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P12
#
# Seed Participant (P12) Data:
# Number of examples per instrument:
# instrument_label
# hho    38
# sd     33
# kd     33
# hhc    29
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P12_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1429 sounds
# Cluster 1: 946 sounds
# Cluster 2: 1316 sounds
# Cluster 3: 2023 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.132
# Davies-Bouldin Index: 2.149
# Calinski-Harabasz Index: 796.214
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P12_confusion.png
#
# ==================================================
# Evaluating with seed participant: P13
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P13
#
# Seed Participant (P13) Data:
# Number of examples per instrument:
# instrument_label
# kd     39
# hhc    36
# sd     35
# hho    24
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P13_cluster.npy
#
# Cluster sizes:
# Cluster 0: 2032 sounds
# Cluster 1: 917 sounds
# Cluster 2: 1321 sounds
# Cluster 3: 1444 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.132
# Davies-Bouldin Index: 2.150
# Calinski-Harabasz Index: 796.282
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P13_confusion.png
#
# ==================================================
# Evaluating with seed participant: P14
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P14
#
# Seed Participant (P14) Data:
# Number of examples per instrument:
# instrument_label
# kd     47
# sd     43
# hhc    42
# hho    27
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P14_cluster.npy
#
# Cluster sizes:
# Cluster 0: 944 sounds
# Cluster 1: 2024 sounds
# Cluster 2: 1311 sounds
# Cluster 3: 1435 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.132
# Davies-Bouldin Index: 2.151
# Calinski-Harabasz Index: 796.205
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P14_confusion.png
#
# ==================================================
# Evaluating with seed participant: P15
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P15
#
# Seed Participant (P15) Data:
# Number of examples per instrument:
# instrument_label
# hhc    44
# kd     37
# sd     36
# hho    34
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P15_cluster.npy
#
# Cluster sizes:
# Cluster 0: 897 sounds
# Cluster 1: 1755 sounds
# Cluster 2: 1442 sounds
# Cluster 3: 1620 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.130
# Davies-Bouldin Index: 2.264
# Calinski-Harabasz Index: 784.209
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P15_confusion.png
#
# ==================================================
# Evaluating with seed participant: P16
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P16
#
# Seed Participant (P16) Data:
# Number of examples per instrument:
# instrument_label
# hhc    52
# kd     52
# sd     52
# hho    25
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P16_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1862 sounds
# Cluster 1: 1838 sounds
# Cluster 2: 1453 sounds
# Cluster 3: 561 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.134
# Davies-Bouldin Index: 2.182
# Calinski-Harabasz Index: 795.161
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P16_confusion.png
#
# ==================================================
# Evaluating with seed participant: P17
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P17
#
# Seed Participant (P17) Data:
# Number of examples per instrument:
# instrument_label
# kd     48
# hho    46
# hhc    25
# sd     25
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P17_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1383 sounds
# Cluster 1: 1062 sounds
# Cluster 2: 1440 sounds
# Cluster 3: 1829 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.135
# Davies-Bouldin Index: 2.226
# Calinski-Harabasz Index: 785.145
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P17_confusion.png
#
# ==================================================
# Evaluating with seed participant: P18
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P18
#
# Seed Participant (P18) Data:
# Number of examples per instrument:
# instrument_label
# kd     88
# hhc    86
# sd     81
# hho    52
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P18_cluster.npy
#
# Cluster sizes:
# Cluster 0: 901 sounds
# Cluster 1: 1415 sounds
# Cluster 2: 1302 sounds
# Cluster 3: 2096 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.123
# Davies-Bouldin Index: 2.111
# Calinski-Harabasz Index: 753.831
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P18_confusion.png
#
# ==================================================
# Evaluating with seed participant: P19
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P19
#
# Seed Participant (P19) Data:
# Number of examples per instrument:
# instrument_label
# sd     45
# hhc    43
# kd     38
# hho    30
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P19_cluster.npy
#
# Cluster sizes:
# Cluster 0: 949 sounds
# Cluster 1: 1774 sounds
# Cluster 2: 1440 sounds
# Cluster 3: 1551 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.130
# Davies-Bouldin Index: 2.255
# Calinski-Harabasz Index: 784.664
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P19_confusion.png
#
# ==================================================
# Evaluating with seed participant: P2
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P2
#
# Seed Participant (P2) Data:
# Number of examples per instrument:
# instrument_label
# hho    40
# kd     38
# sd     37
# hhc    26
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P2_cluster.npy
#
# Cluster sizes:
# Cluster 0: 2034 sounds
# Cluster 1: 942 sounds
# Cluster 2: 1304 sounds
# Cluster 3: 1434 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.132
# Davies-Bouldin Index: 2.151
# Calinski-Harabasz Index: 796.157
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P2_confusion.png
#
# ==================================================
# Evaluating with seed participant: P20
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P20
#
# Seed Participant (P20) Data:
# Number of examples per instrument:
# instrument_label
# kd     46
# sd     43
# hhc    32
# hho    32
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P20_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1756 sounds
# Cluster 1: 1556 sounds
# Cluster 2: 1441 sounds
# Cluster 3: 961 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.130
# Davies-Bouldin Index: 2.255
# Calinski-Harabasz Index: 784.628
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P20_confusion.png
#
# ==================================================
# Evaluating with seed participant: P21
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P21
#
# Seed Participant (P21) Data:
# Number of examples per instrument:
# instrument_label
# kd     94
# sd     76
# hho    33
# hhc    29
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P21_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1839 sounds
# Cluster 1: 1861 sounds
# Cluster 2: 1453 sounds
# Cluster 3: 561 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.134
# Davies-Bouldin Index: 2.182
# Calinski-Harabasz Index: 795.164
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P21_confusion.png
#
# ==================================================
# Evaluating with seed participant: P22
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P22
#
# Seed Participant (P22) Data:
# Number of examples per instrument:
# instrument_label
# kd     107
# hhc     74
# sd      66
# hho     46
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P22_cluster.npy
#
# Cluster sizes:
# Cluster 0: 2033 sounds
# Cluster 1: 1428 sounds
# Cluster 2: 1317 sounds
# Cluster 3: 936 sounds
#
# Clustering Metrics:
# Silhouette Score: 0.132
# Davies-Bouldin Index: 2.148
# Calinski-Harabasz Index: 796.226
#
# Saved confusion matrix visualization to: ../../../cluster_assignments/visualization/clustering_eval/seeded_kmeans_P22_confusion.png
#
# ==================================================
# Evaluating with seed participant: P23
# ==================================================
# Loading features from: ../../../extracted_features/features/mfcc_extracted_features.npy
# Loading segment info from: ../../../segment_info/segment_info_base_names.csv
#
# Feature matrix shape: (5714, 12)
# Number of segments: 5714
#
# Getting centroids from participant P23
#
# Seed Participant (P23) Data:
# Number of examples per instrument:
# instrument_label
# kd     65
# sd     60
# hho    41
# hhc    35
# Name: count, dtype: int64
#
# Centroid shape for hhc: (12,)
#
# Centroid shape for hho: (12,)
#
# Centroid shape for kd: (12,)
#
# Centroid shape for sd: (12,)
# Initial centroids shape: (4, 12)
#
# Performing seeded k-means clustering...
#
# Saved cluster assignments to: ../../../cluster_assignments/seeded_kmeans/seeded_kmeans_P23_cluster.npy
#
# Cluster sizes:
# Cluster 0: 1595 sounds
# Cluster 1: 1690 sounds
# Cluster 2: 1406 sounds
# Cluster 3: 1023 sounds
