# %%
import pandas as pd
import numpy as np
import numpy as np
def dummy_npwarn_decorator_factory():
  def npwarn_decorator(x):
    return x
  return npwarn_decorator
np._no_nep50_warning = getattr(np, '_no_nep50_warning', dummy_npwarn_decorator_factory)
from pathlib import Path
import librosa
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchaudio
from sklearn.model_selection import GroupKFold
import random

# %%
def reduce_phoneme(phoneme):
    """Apply the reduced phoneme table from the paper"""
    reductions = {
        'tʃ': 'tS', 'tʒ': 'tS', 'dʒ': 'dZ',
        'kχ': 'k', 'ks': 'k',
        'h': 'h', 'x': 'x'
    }
    return reductions.get(phoneme, phoneme)

def create_syllable_table():
    """
    Create syllable labels following the paper's method:
    - No delimiter between onset and coda
    - Use reduced phoneme table
    - Silence represented by 'x'
    """
    segment_info = pd.read_csv('../../segment_info/segment_info.csv')
    
    # Apply phoneme reductions
    segment_info['onset_reduced'] = segment_info['onset_phoneme'].apply(reduce_phoneme)
    segment_info['coda_reduced'] = segment_info['coda_phoneme'].apply(reduce_phoneme)
    
    # Create syllable strings (no delimiter)
    segment_info['syllable'] = segment_info.apply(
        lambda row: f"{row['onset_reduced']}{row['coda_reduced']}", 
        axis=1
    )
    
    # Create syllable ID mapping
    unique_syllables = sorted(segment_info['syllable'].unique())
    syllable_to_id = {syl: idx for idx, syl in enumerate(unique_syllables)}
    
    # Add syllable IDs
    segment_info['syllable_id'] = segment_info['syllable'].map(syllable_to_id)
    
    # Print statistics
    print(f"Total unique syllables: {len(unique_syllables)}")
    print("\nSyllable ID mapping:")
    for syl, idx in syllable_to_id.items():
        print(f"{syl}: {idx}")
    
    # Print example distribution
    print("\nExample syllables for each instrument:")
    for instrument in segment_info['instrument_label'].unique():
        examples = segment_info[segment_info['instrument_label'] == instrument].iloc[:3]
        print(f"\n{instrument}:")
        for _, row in examples.iterrows():
            print(f"  {row['syllable']} (ID: {row['syllable_id']})")
            
    return segment_info, syllable_to_id

# %%
def compute_log_mel_patch(input_audio, sr=44100, duration=0.560, 
                         n_mels=64, n_fft=2048, hop_length=512):
    """
    Compute log-Mel spectrogram patch from audio file or array.
    
    Args:
        input_audio: Either a path to an audio file or a numpy array of audio samples
        sr: Sample rate (default: 44100)
        duration: Duration in seconds (default: 0.560)
        n_mels: Number of Mel bands (default: 64)
        n_fft: FFT window size (default: 2048)
        hop_length: Number of samples between successive frames (default: 512)
    """
    # Load audio if path is provided
    if isinstance(input_audio, (str, Path)):
        audio, _ = librosa.load(input_audio, sr=sr)
    else:
        audio = input_audio
    
    # Cut/pad to fixed duration
    target_length = int(duration * sr)
    if len(audio) > target_length:
        audio = audio[:target_length]
    else:
        audio = np.pad(audio, (0, target_length - len(audio)))
    
    # Compute Mel spectrogram
    mel_spec = librosa.feature.melspectrogram(
        y=audio,
        sr=sr,
        n_mels=n_mels,
        n_fft=n_fft,
        hop_length=hop_length
    )
    
    # Convert to log scale
    log_mel = np.log(mel_spec + 1e-4)
    
    # Min-max normalization
    log_mel = (log_mel - log_mel.min()) / (log_mel.max() - log_mel.min())
    
    # Add channel dimension
    log_mel = np.expand_dims(log_mel, axis=0)
    
    return log_mel

def augment_audio(audio, sr=44100):
    """
    Apply random pitch shift and time stretch augmentation.
    Returns 10 augmented versions.
    """
    augmented = []
    for _ in range(10):
        # Random parameters
        pitch_shift = random.uniform(-1.5, 1.5)
        time_stretch = random.uniform(0.8, 1.2)
        
        # Randomly choose order of operations
        if random.random() < 0.5:
            # Pitch shift then stretch
            aug_audio = librosa.effects.pitch_shift(audio, sr=sr, n_steps=pitch_shift)
            aug_audio = librosa.effects.time_stretch(aug_audio, rate=time_stretch)
        else:
            # Stretch then pitch shift
            aug_audio = librosa.effects.time_stretch(audio, rate=time_stretch)
            aug_audio = librosa.effects.pitch_shift(aug_audio, sr=sr, n_steps=pitch_shift)
        
        augmented.append(aug_audio)
    
    return augmented

# %%
class SyllableCNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        
        # Convolutional blocks
        self.conv_blocks = nn.Sequential(
            # Block 1: Input (1, 64, 48) -> Output (8, 32, 24)
            nn.Conv2d(1, 8, 3, padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.Conv2d(8, 8, 3, padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            # Block 2: (8, 32, 24) -> (16, 16, 12)
            nn.Conv2d(8, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            # Block 3: (16, 16, 12) -> (32, 8, 6)
            nn.Conv2d(16, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            # Block 4: (32, 8, 6) -> (64, 4, 3)
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )
        
        # Calculate the size of flattened features
        self.flat_features = 64 * 4 * 3  # 768 features after convolution
        
        # Embedding layer
        self.embedding = nn.Linear(self.flat_features, 1024)
        
        # Classification layer
        self.classifier = nn.Linear(1024, num_classes)
    
    def forward(self, x):
        # Convolutional blocks
        x = self.conv_blocks(x)
        
        # Flatten: (batch_size, 64, 4, 3) -> (batch_size, 768)
        x = x.view(x.size(0), -1)
        
        # Embedding: (batch_size, 768) -> (batch_size, 1024)
        embeddings = self.embedding(x)
        x = nn.ReLU()(embeddings)
        
        # Classification: (batch_size, 1024) -> (batch_size, num_classes)
        x = self.classifier(x)
        
        return x, embeddings

    def get_embedding_dim(self):
        return self.flat_features

# %%
def train_fold(model, train_loader, val_loader, device, fold):
    """
    Train one fold of the CNN model.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.1, patience=5, verbose=True
    )
    
    best_val_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    for epoch in range(100):  # Maximum 100 epochs
        # Training
        model.train()
        train_loss = 0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            
            optimizer.zero_grad()
            outputs, _ = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
        
        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                outputs, _ = model(batch_x)
                val_loss += criterion(outputs, batch_y).item()
        
        # Update learning rate
        scheduler.step(val_loss)
        
        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1
        
        print(f"Epoch {epoch}: train_loss = {train_loss:.4f}, val_loss = {val_loss:.4f}")
        
        # Early stopping
        if patience_counter >= 10:
            print("Early stopping triggered")
            break
    
    # Save best model
    torch.save(best_model_state, f'cnn_model_fold_{fold}.pt')
    return best_model_state

# %%
import os
# Test file paths
def test_file_paths():
    segment_info = pd.read_csv('../../segment_info/segment_info.csv')
    print("Testing first 5 file paths...")
    for idx, row in segment_info.head().iterrows():
        file_path = row['segment_path']
        print(f"\nChecking file: {file_path}")
        full_path = os.path.abspath(os.path.join(os.path.dirname('../../segment_info/segment_info.csv'), file_path))
        print(f"Full path: {full_path}")
        print(f"File exists: {os.path.exists(full_path)}")

test_file_paths()
# Out:
# Testing first 5 file paths...
#
# Checking file: ../segments/AVP_P1_hhc_0000.wav
# Full path: /Users/arul/ML/BEATBOX/projectFiles/segments/AVP_P1_hhc_0000.wav
# File exists: True
#
# Checking file: ../segments/AVP_P1_hhc_0001.wav
# Full path: /Users/arul/ML/BEATBOX/projectFiles/segments/AVP_P1_hhc_0001.wav
# File exists: True
#
# Checking file: ../segments/AVP_P1_hhc_0002.wav
# Full path: /Users/arul/ML/BEATBOX/projectFiles/segments/AVP_P1_hhc_0002.wav
# File exists: True
#
# Checking file: ../segments/AVP_P1_hhc_0003.wav
# Full path: /Users/arul/ML/BEATBOX/projectFiles/segments/AVP_P1_hhc_0003.wav
# File exists: True
#
# Checking file: ../segments/AVP_P1_hhc_0004.wav
# Full path: /Users/arul/ML/BEATBOX/projectFiles/segments/AVP_P1_hhc_0004.wav
# File exists: True

# %%
def main():
    print("Starting CNN training pipeline...")
    
    # 1. Create syllable table and fix paths
    print("\nStep 1: Creating syllable table and fixing paths...")
    segment_info, syllable_to_id = create_syllable_table()
    
    # Fix the paths by adding an extra '../'
    segment_info['segment_path'] = segment_info['segment_path'].apply(
        lambda x: f"../../{x[3:]}" if x.startswith('../') else x
    )
    
    num_classes = len(syllable_to_id)
    print(f"Created syllable mapping with {num_classes} classes")
    
    # Test a few paths to make sure they're correct
    print("\nTesting fixed paths:")
    for path in segment_info['segment_path'].head():
        print(f"Fixed path: {path}")
        print(f"Exists: {os.path.exists(path)}")
        
    # 2. Create participant-stratified folds
    print("\nStep 2: Creating participant folds...")
    group_kfold = GroupKFold(n_splits=5)
    participants = segment_info['participant_id'].unique()
    print(f"Total participants: {len(participants)}")
    
    # Store embeddings for all segments
    print("\nInitializing embedding storage...")
    all_embeddings = np.zeros((len(segment_info), 1024))
    print(f"Will store embeddings for {len(segment_info)} segments")
    
    # Process each fold
    for fold, (train_val_idx, test_idx) in enumerate(group_kfold.split(
            np.arange(len(participants)), groups=participants)):  # Modified this line
        
        print(f"\nProcessing Fold {fold + 1}/5")
        
        train_val_participants = participants[train_val_idx]
        print(f"Train/Val participants: {len(train_val_participants)}")
        
        # Split train_val into train and validation
        train_participants = train_val_participants[:32]
        val_participants = train_val_participants[32:]
        print(f"Training participants: {len(train_participants)}")
        print(f"Validation participants: {len(val_participants)}")
        
        # Get segment indices for each set
        train_mask = segment_info['participant_id'].isin(train_participants)
        val_mask = segment_info['participant_id'].isin(val_participants)
        
        print("\nProcessing training data...")
        # Process training data with augmentation
        X_train = []
        y_train = []
        for idx in segment_info[train_mask].index:
            if len(X_train) % 100 == 0:
                print(f"Processed {len(X_train)} training samples...")
                
            # Original segment
            file_path = segment_info.loc[idx, 'segment_path']
            print(f"Processing file: {file_path}")  # Debug print
            
            try:
                mel_spec = compute_log_mel_patch(file_path)
                X_train.append(mel_spec)
                y_train.append(segment_info.loc[idx, 'syllable_id'])
                
                # Augmented versions
                audio, sr = librosa.load(file_path, sr=44100)
                aug_audios = augment_audio(audio, sr)
                for aug_audio in aug_audios:
                    mel_spec = compute_log_mel_patch(aug_audio)
                    X_train.append(mel_spec)
                    y_train.append(segment_info.loc[idx, 'syllable_id'])
            except Exception as e:
                print(f"Error processing {file_path}: {str(e)}")
                continue
        
        print("\nProcessing validation data...")
        # Process validation data (no augmentation)
        X_val = []
        y_val = []
        for idx in segment_info[val_mask].index:
            if len(X_val) % 100 == 0:
                print(f"Processed {len(X_val)} validation samples...")
                
            try:
                mel_spec = compute_log_mel_patch(segment_info.loc[idx, 'segment_path'])
                X_val.append(mel_spec)
                y_val.append(segment_info.loc[idx, 'syllable_id'])
            except Exception as e:
                print(f"Error processing validation sample: {str(e)}")
                continue
        
        print("\nConverting to numpy arrays...")
        # Convert to numpy arrays
        X_train = np.stack(X_train)
        y_train = np.array(y_train)
        X_val = np.stack(X_val)
        y_val = np.array(y_val)
        
        print(f"\nFold {fold + 1} data shapes:")
        print(f"X_train shape: {X_train.shape}")
        print(f"X_val shape: {X_val.shape}")
        print("\nTraining syllable distribution:")
        print(pd.Series(y_train).value_counts().sort_index())
        
        print("\nCreating data loaders...")
        # Create data loaders
        train_dataset = torch.utils.data.TensorDataset(
            torch.FloatTensor(X_train),
            torch.LongTensor(y_train)
        )
        val_dataset = torch.utils.data.TensorDataset(
            torch.FloatTensor(X_val),
            torch.LongTensor(y_val)
        )
        
        train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=128)
        
        print("\nInitializing model...")
        # Train model
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print(f"Using device: {device}")
        model = SyllableCNN(num_classes).to(device)
        
        print("\nTraining model...")
        best_model_state = train_fold(model, train_loader, val_loader, device, fold)
        
        print("\nGenerating embeddings...")
        # Generate embeddings for all segments using this fold's model
        model.load_state_dict(best_model_state)
        model.eval()
        
        with torch.no_grad():
            for idx in range(len(segment_info)):
                if idx % 100 == 0:
                    print(f"Generated embeddings for {idx}/{len(segment_info)} segments...")
                try:
                    mel_spec = compute_log_mel_patch(segment_info.loc[idx, 'segment_path'])
                    mel_spec = torch.FloatTensor(mel_spec).unsqueeze(0).to(device)
                    _, embedding = model(mel_spec)
                    all_embeddings[idx] = embedding.cpu().numpy()
                except Exception as e:
                    print(f"Error generating embedding for segment {idx}: {str(e)}")
                    continue
    
    print("\nSaving embeddings...")
    np.save('cnn_syllable_features.npy', all_embeddings)
    print("Done!")

if __name__ == "__main__":
    main()
# Out:
# Starting CNN training pipeline...
#
# Step 1: Creating syllable table and fixing paths...
# Total unique syllables: 51
#
# Syllable ID mapping:
# !-x: 0
# dʒ-u: 1
# k-a: 2
# k-h: 3
# k-x: 4
# k-ʊ: 5
# kg-h: 6
# kg-x: 7
# kʃ-h: 8
# kʃ-x: 9
# p-a: 10
# p-h: 11
# p-i: 12
# p-o: 13
# p-u: 14
# p-x: 15
# p-ə: 16
# p-ɯ: 17
# p-ʊ: 18
# p-ʌ: 19
# s-x: 20
# t-a: 21
# t-e: 22
# t-h: 23
# t-i: 24
# t-u: 25
# t-x: 26
# t-ɐ: 27
# t-ɘ: 28
# t-ɪ: 29
# t-ɯ: 30
# t-ʊ: 31
# ts-a: 32
# ts-h: 33
# ts-x: 34
# ts-ɪ: 35
# tɕ-h: 36
# tɕ-x: 37
# tʃ-I: 38
# tʃ-a: 39
# tʃ-h: 40
# tʃ-i: 41
# tʃ-x: 42
# tʃ-æ: 43
# tʃ-œ: 44
# tʃ-ɘ: 45
# tʒ-h: 46
# tʒ-x: 47
# ʔ-a: 48
# ʡʢ-u: 49
# ʡʢ-x: 50
#
# Example syllables for each instrument:
#
# hhc:
#   tʃ-x (ID: 42)
#   tʃ-æ (ID: 43)
#   tʃ-æ (ID: 43)
#
# hho:
#   tʃ-x (ID: 42)
#   tʃ-i (ID: 41)
#   tʃ-i (ID: 41)
#
# kd:
#   p-ə (ID: 16)
#   p-ə (ID: 16)
#   p-ə (ID: 16)
#
# sd:
#   t-e (ID: 22)
#   t-e (ID: 22)
#   t-e (ID: 22)
# Created syllable mapping with 51 classes
#
# Testing fixed paths:
# Fixed path: ../../segments/AVP_P1_hhc_0000.wav
# Exists: True
# Fixed path: ../../segments/AVP_P1_hhc_0001.wav
# Exists: True
# Fixed path: ../../segments/AVP_P1_hhc_0002.wav
# Exists: True
# Fixed path: ../../segments/AVP_P1_hhc_0003.wav
# Exists: True
# Fixed path: ../../segments/AVP_P1_hhc_0004.wav
# Exists: True
#
# Step 2: Creating participant folds...
# Total participants: 68
#
# Initializing embedding storage...
# Will store embeddings for 5714 segments
#
# Processing Fold 1/5
# Train/Val participants: 54
# Training participants: 32
# Validation participants: 22
#
# Processing training data...
# Processed 0 training samples...
# Processing file: ../../segments/AVP_P1_hhc_0000.wav
# Processing file: ../../segments/AVP_P1_hhc_0001.wav
# Processing file: ../../segments/AVP_P1_hhc_0002.wav
# Processing file: ../../segments/AVP_P1_hhc_0003.wav
# Processing file: ../../segments/AVP_P1_hhc_0004.wav
# Processing file: ../../segments/AVP_P1_hhc_0005.wav
# Processing file: ../../segments/AVP_P1_hhc_0006.wav
# Processing file: ../../segments/AVP_P1_hhc_0007.wav
# Processing file: ../../segments/AVP_P1_hhc_0008.wav
# Processing file: ../../segments/AVP_P1_hhc_0009.wav
# Processing file: ../../segments/AVP_P1_hhc_0010.wav
# Processing file: ../../segments/AVP_P1_hhc_0011.wav
# Processing file: ../../segments/AVP_P1_hhc_0012.wav
# Processing file: ../../segments/AVP_P1_hhc_0013.wav
# Processing file: ../../segments/AVP_P1_hhc_0014.wav
# Processing file: ../../segments/AVP_P1_hhc_0015.wav
# Processing file: ../../segments/AVP_P1_hhc_0016.wav
# Processing file: ../../segments/AVP_P1_hhc_0017.wav
# Processing file: ../../segments/AVP_P1_hhc_0018.wav
# Processing file: ../../segments/AVP_P1_hhc_0019.wav
# Processing file: ../../segments/AVP_P1_hhc_0020.wav
# Processing file: ../../segments/AVP_P1_hhc_0021.wav
# Processing file: ../../segments/AVP_P1_hhc_0022.wav
# Processing file: ../../segments/AVP_P1_hhc_0023.wav
# Processing file: ../../segments/AVP_P1_hhc_0024.wav
# Processing file: ../../segments/AVP_P1_hhc_0025.wav
# Processing file: ../../segments/AVP_P1_hhc_0026.wav
# Processing file: ../../segments/AVP_P1_hhc_0027.wav
# Processing file: ../../segments/AVP_P1_hhc_0028.wav
# Processing file: ../../segments/AVP_P1_hho_0029.wav
# Processing file: ../../segments/AVP_P1_hho_0030.wav
# Processing file: ../../segments/AVP_P1_hho_0031.wav
# Processing file: ../../segments/AVP_P1_hho_0032.wav
# Processing file: ../../segments/AVP_P1_hho_0033.wav
# Processing file: ../../segments/AVP_P1_hho_0034.wav
# Processing file: ../../segments/AVP_P1_hho_0035.wav
# Processing file: ../../segments/AVP_P1_hho_0036.wav
# Processing file: ../../segments/AVP_P1_hho_0037.wav
# Processing file: ../../segments/AVP_P1_hho_0038.wav
# Processing file: ../../segments/AVP_P1_hho_0039.wav
# Processing file: ../../segments/AVP_P1_hho_0040.wav
# Processing file: ../../segments/AVP_P1_hho_0041.wav
# Processing file: ../../segments/AVP_P1_hho_0042.wav
# Processing file: ../../segments/AVP_P1_hho_0043.wav
# Processing file: ../../segments/AVP_P1_hho_0044.wav
# Processing file: ../../segments/AVP_P1_hho_0045.wav
# Processing file: ../../segments/AVP_P1_hho_0046.wav
# Processing file: ../../segments/AVP_P1_hho_0047.wav
# Processing file: ../../segments/AVP_P1_hho_0048.wav
# Processing file: ../../segments/AVP_P1_hho_0049.wav
# Processing file: ../../segments/AVP_P1_hho_0050.wav
# Processing file: ../../segments/AVP_P1_hho_0051.wav
# Processing file: ../../segments/AVP_P1_hho_0052.wav
# Processing file: ../../segments/AVP_P1_hho_0053.wav
# Processing file: ../../segments/AVP_P1_hho_0054.wav
# Processing file: ../../segments/AVP_P1_kd_0055.wav
# Processing file: ../../segments/AVP_P1_hho_0056.wav
# Processing file: ../../segments/AVP_P1_kd_0057.wav
# Processing file: ../../segments/AVP_P1_kd_0058.wav
# Processing file: ../../segments/AVP_P1_hho_0059.wav
# Processing file: ../../segments/AVP_P1_kd_0060.wav
# Processing file: ../../segments/AVP_P1_kd_0061.wav
# Processing file: ../../segments/AVP_P1_sd_0062.wav
# Processing file: ../../segments/AVP_P1_hho_0063.wav
# Processing file: ../../segments/AVP_P1_hhc_0064.wav
# Processing file: ../../segments/AVP_P1_kd_0065.wav
# Processing file: ../../segments/AVP_P1_kd_0066.wav
# Processing file: ../../segments/AVP_P1_hho_0067.wav
# Processing file: ../../segments/AVP_P1_kd_0068.wav
# Processing file: ../../segments/AVP_P1_kd_0069.wav
# Processing file: ../../segments/AVP_P1_hho_0070.wav
# Processing file: ../../segments/AVP_P1_hhc_0071.wav
# Processing file: ../../segments/AVP_P1_hhc_0072.wav
# Processing file: ../../segments/AVP_P1_kd_0073.wav
# Processing file: ../../segments/AVP_P1_kd_0074.wav
# Processing file: ../../segments/AVP_P1_kd_0075.wav
# Processing file: ../../segments/AVP_P1_kd_0076.wav
# Processing file: ../../segments/AVP_P1_kd_0077.wav
# Processing file: ../../segments/AVP_P1_kd_0078.wav
# Processing file: ../../segments/AVP_P1_kd_0079.wav
# Processing file: ../../segments/AVP_P1_kd_0080.wav
# Processing file: ../../segments/AVP_P1_kd_0081.wav
# Processing file: ../../segments/AVP_P1_kd_0082.wav
# Processing file: ../../segments/AVP_P1_kd_0083.wav
# Processing file: ../../segments/AVP_P1_kd_0084.wav
# Processing file: ../../segments/AVP_P1_kd_0085.wav
# Processing file: ../../segments/AVP_P1_kd_0086.wav
# Processing file: ../../segments/AVP_P1_kd_0087.wav
# Processing file: ../../segments/AVP_P1_kd_0088.wav
# Processing file: ../../segments/AVP_P1_kd_0089.wav
# Processing file: ../../segments/AVP_P1_kd_0090.wav
# Processing file: ../../segments/AVP_P1_kd_0091.wav
# Processing file: ../../segments/AVP_P1_kd_0092.wav
# Processing file: ../../segments/AVP_P1_kd_0093.wav
# Processing file: ../../segments/AVP_P1_kd_0094.wav
# Processing file: ../../segments/AVP_P1_kd_0095.wav
# Processing file: ../../segments/AVP_P1_kd_0096.wav
# Processing file: ../../segments/AVP_P1_kd_0097.wav
# Processing file: ../../segments/AVP_P1_kd_0098.wav
# Processing file: ../../segments/AVP_P1_kd_0099.wav
# Processed 1100 training samples...
# Processing file: ../../segments/AVP_P1_kd_0100.wav
# Processing file: ../../segments/AVP_P1_kd_0101.wav
# Processing file: ../../segments/AVP_P1_sd_0102.wav
# Processing file: ../../segments/AVP_P1_sd_0103.wav
# Processing file: ../../segments/AVP_P1_sd_0104.wav
# Processing file: ../../segments/AVP_P1_sd_0105.wav
# Processing file: ../../segments/AVP_P1_sd_0106.wav
# Processing file: ../../segments/AVP_P1_sd_0107.wav
# Processing file: ../../segments/AVP_P1_sd_0108.wav
# Processing file: ../../segments/AVP_P1_sd_0109.wav
# Processing file: ../../segments/AVP_P1_sd_0110.wav
# Processing file: ../../segments/AVP_P1_sd_0111.wav
# Processing file: ../../segments/AVP_P1_sd_0112.wav
# Processing file: ../../segments/AVP_P1_sd_0113.wav
# Processing file: ../../segments/AVP_P1_sd_0114.wav
# Processing file: ../../segments/AVP_P1_sd_0115.wav
# Processing file: ../../segments/AVP_P1_sd_0116.wav
# Processing file: ../../segments/AVP_P1_sd_0117.wav
# Processing file: ../../segments/AVP_P1_sd_0118.wav
# Processing file: ../../segments/AVP_P1_sd_0119.wav
# Processing file: ../../segments/AVP_P1_sd_0120.wav
# Processing file: ../../segments/AVP_P1_sd_0121.wav
# Processing file: ../../segments/AVP_P1_sd_0122.wav
# Processing file: ../../segments/AVP_P1_sd_0123.wav
# Processing file: ../../segments/AVP_P1_sd_0124.wav
# Processing file: ../../segments/AVP_P1_sd_0125.wav
# Processing file: ../../segments/AVP_P1_sd_0126.wav
# Processing file: ../../segments/AVP_P1_sd_0127.wav
# Processing file: ../../segments/AVP_P11_hhc_0296.wav
# Processing file: ../../segments/AVP_P11_hhc_0297.wav
# Processing file: ../../segments/AVP_P11_hhc_0298.wav
# Processing file: ../../segments/AVP_P11_hhc_0299.wav
# Processing file: ../../segments/AVP_P11_hhc_0300.wav
# Processing file: ../../segments/AVP_P11_hhc_0301.wav
# Processing file: ../../segments/AVP_P11_hhc_0302.wav
# Processing file: ../../segments/AVP_P11_hhc_0303.wav
# Processing file: ../../segments/AVP_P11_hhc_0304.wav
# Processing file: ../../segments/AVP_P11_hhc_0305.wav
# Processing file: ../../segments/AVP_P11_hhc_0306.wav
# Processing file: ../../segments/AVP_P11_hhc_0307.wav
# Processing file: ../../segments/AVP_P11_hhc_0308.wav
# Processing file: ../../segments/AVP_P11_hhc_0309.wav
# Processing file: ../../segments/AVP_P11_hhc_0310.wav
# Processing file: ../../segments/AVP_P11_hhc_0311.wav
# Processing file: ../../segments/AVP_P11_hhc_0312.wav
# Processing file: ../../segments/AVP_P11_hhc_0313.wav
# Processing file: ../../segments/AVP_P11_hhc_0314.wav
# Processing file: ../../segments/AVP_P11_hhc_0315.wav
# Processing file: ../../segments/AVP_P11_hhc_0316.wav
# Processing file: ../../segments/AVP_P11_hhc_0317.wav
# Processing file: ../../segments/AVP_P11_hhc_0318.wav
# Processing file: ../../segments/AVP_P11_hhc_0319.wav
# Processing file: ../../segments/AVP_P11_hhc_0320.wav
# Processing file: ../../segments/AVP_P11_hhc_0321.wav
# Processing file: ../../segments/AVP_P11_hhc_0322.wav
# Processing file: ../../segments/AVP_P11_hho_0323.wav
# Processing file: ../../segments/AVP_P11_hho_0324.wav
# Processing file: ../../segments/AVP_P11_hho_0325.wav
# Processing file: ../../segments/AVP_P11_hho_0326.wav
# Processing file: ../../segments/AVP_P11_hho_0327.wav
# Processing file: ../../segments/AVP_P11_hho_0328.wav
# Processing file: ../../segments/AVP_P11_hho_0329.wav
# Processing file: ../../segments/AVP_P11_hho_0330.wav
# Processing file: ../../segments/AVP_P11_hho_0331.wav
# Processing file: ../../segments/AVP_P11_hho_0332.wav
# Processing file: ../../segments/AVP_P11_hho_0333.wav
# Processing file: ../../segments/AVP_P11_hho_0334.wav
# Processing file: ../../segments/AVP_P11_hho_0335.wav
# Processing file: ../../segments/AVP_P11_hho_0336.wav
# Processing file: ../../segments/AVP_P11_hho_0337.wav
# Processing file: ../../segments/AVP_P11_hho_0338.wav
# Processing file: ../../segments/AVP_P11_hho_0339.wav
# Processing file: ../../segments/AVP_P11_hho_0340.wav
# Processing file: ../../segments/AVP_P11_hho_0341.wav
# Processing file: ../../segments/AVP_P11_hho_0342.wav
# Processing file: ../../segments/AVP_P11_hho_0343.wav
# Processing file: ../../segments/AVP_P11_hho_0344.wav
# Processing file: ../../segments/AVP_P11_hho_0345.wav
# Processing file: ../../segments/AVP_P11_hho_0346.wav
# Processing file: ../../segments/AVP_P11_hho_0347.wav
# Processing file: ../../segments/AVP_P11_hho_0348.wav
# Processing file: ../../segments/AVP_P11_hho_0349.wav
# Processing file: ../../segments/AVP_P11_hho_0350.wav
# Processing file: ../../segments/AVP_P11_hho_0351.wav
# Processing file: ../../segments/AVP_P11_sd_0352.wav
# Processing file: ../../segments/AVP_P11_hhc_0353.wav
# Processing file: ../../segments/AVP_P11_hhc_0354.wav
# Processing file: ../../segments/AVP_P11_kd_0355.wav
# Processing file: ../../segments/AVP_P11_sd_0356.wav
# Processing file: ../../segments/AVP_P11_hhc_0357.wav
# Processing file: ../../segments/AVP_P11_hho_0358.wav
# Processing file: ../../segments/AVP_P11_kd_0359.wav
# Processing file: ../../segments/AVP_P11_sd_0360.wav
# Processing file: ../../segments/AVP_P11_hhc_0361.wav
# Processing file: ../../segments/AVP_P11_hho_0362.wav
# Processing file: ../../segments/AVP_P11_kd_0363.wav
# Processing file: ../../segments/AVP_P11_sd_0364.wav
# Processing file: ../../segments/AVP_P11_hhc_0365.wav
# Processing file: ../../segments/AVP_P11_kd_0366.wav
# Processing file: ../../segments/AVP_P11_kd_0367.wav
# Processed 2200 training samples...
# Processing file: ../../segments/AVP_P11_sd_0368.wav
# Processing file: ../../segments/AVP_P11_hhc_0369.wav
# Processing file: ../../segments/AVP_P11_kd_0370.wav
# Processing file: ../../segments/AVP_P11_kd_0371.wav
# Processing file: ../../segments/AVP_P11_sd_0372.wav
# Processing file: ../../segments/AVP_P11_hhc_0373.wav
# Processing file: ../../segments/AVP_P11_hho_0374.wav
# Processing file: ../../segments/AVP_P11_kd_0375.wav
# Processing file: ../../segments/AVP_P11_sd_0376.wav
# Processing file: ../../segments/AVP_P11_hhc_0377.wav
# Processing file: ../../segments/AVP_P11_kd_0378.wav
# Processing file: ../../segments/AVP_P11_kd_0379.wav
# Processing file: ../../segments/AVP_P11_sd_0380.wav
# Processing file: ../../segments/AVP_P11_hhc_0381.wav
# Processing file: ../../segments/AVP_P11_hho_0382.wav
# Processing file: ../../segments/AVP_P11_kd_0383.wav
# Processing file: ../../segments/AVP_P11_sd_0384.wav
# Processing file: ../../segments/AVP_P11_hhc_0385.wav
# Processing file: ../../segments/AVP_P11_kd_0386.wav
# Processing file: ../../segments/AVP_P11_kd_0387.wav
# Processing file: ../../segments/AVP_P11_sd_0388.wav
# Processing file: ../../segments/AVP_P11_hhc_0389.wav
# Processing file: ../../segments/AVP_P11_hho_0390.wav
# Processing file: ../../segments/AVP_P11_kd_0391.wav
# Processing file: ../../segments/AVP_P11_sd_0392.wav
# Processing file: ../../segments/AVP_P11_hhc_0393.wav
# Processing file: ../../segments/AVP_P11_kd_0394.wav
# Processing file: ../../segments/AVP_P11_kd_0395.wav
# Processing file: ../../segments/AVP_P11_sd_0396.wav
# Processing file: ../../segments/AVP_P11_hhc_0397.wav
# Processing file: ../../segments/AVP_P11_hho_0398.wav
# Processing file: ../../segments/AVP_P11_kd_0399.wav
# Processing file: ../../segments/AVP_P11_sd_0400.wav
# Processing file: ../../segments/AVP_P11_hhc_0401.wav
# Processing file: ../../segments/AVP_P11_kd_0402.wav
# Processing file: ../../segments/AVP_P11_kd_0403.wav
# Processing file: ../../segments/AVP_P11_sd_0404.wav
# Processing file: ../../segments/AVP_P11_hhc_0405.wav
# Processing file: ../../segments/AVP_P11_hho_0406.wav
# Processing file: ../../segments/AVP_P11_kd_0407.wav
# Processing file: ../../segments/AVP_P11_sd_0408.wav
# Processing file: ../../segments/AVP_P11_hhc_0409.wav
# Processing file: ../../segments/AVP_P11_kd_0410.wav
# Processing file: ../../segments/AVP_P11_kd_0411.wav
# Processing file: ../../segments/AVP_P11_sd_0412.wav
# Processing file: ../../segments/AVP_P11_hhc_0413.wav
# Processing file: ../../segments/AVP_P11_kd_0414.wav
# Processing file: ../../segments/AVP_P11_kd_0415.wav
# Processing file: ../../segments/AVP_P11_sd_0416.wav
# Processing file: ../../segments/AVP_P11_hhc_0417.wav
# Processing file: ../../segments/AVP_P11_hho_0418.wav
# Processing file: ../../segments/AVP_P11_kd_0419.wav
# Processing file: ../../segments/AVP_P11_sd_0420.wav
# Processing file: ../../segments/AVP_P11_hhc_0421.wav
# Processing file: ../../segments/AVP_P11_kd_0422.wav
# Processing file: ../../segments/AVP_P11_sd_0423.wav
# Processing file: ../../segments/AVP_P11_hhc_0424.wav
# Processing file: ../../segments/AVP_P11_hho_0425.wav
# Processing file: ../../segments/AVP_P11_kd_0426.wav
# Processing file: ../../segments/AVP_P11_sd_0427.wav
# Processing file: ../../segments/AVP_P11_hhc_0428.wav
# Processing file: ../../segments/AVP_P11_kd_0429.wav
# Processing file: ../../segments/AVP_P11_kd_0430.wav
# Processing file: ../../segments/AVP_P11_sd_0431.wav
# Processing file: ../../segments/AVP_P11_hhc_0432.wav
# Processing file: ../../segments/AVP_P11_kd_0433.wav
# Processing file: ../../segments/AVP_P11_kd_0434.wav
# Processing file: ../../segments/AVP_P11_kd_0435.wav
# Processing file: ../../segments/AVP_P11_kd_0436.wav
# Processing file: ../../segments/AVP_P11_kd_0437.wav
# Processing file: ../../segments/AVP_P11_kd_0438.wav
# Processing file: ../../segments/AVP_P11_kd_0439.wav
# Processing file: ../../segments/AVP_P11_kd_0440.wav
# Processing file: ../../segments/AVP_P11_kd_0441.wav
# Processing file: ../../segments/AVP_P11_kd_0442.wav
# Processing file: ../../segments/AVP_P11_kd_0443.wav
# Processing file: ../../segments/AVP_P11_kd_0444.wav
# Processing file: ../../segments/AVP_P11_kd_0445.wav
# Processing file: ../../segments/AVP_P11_kd_0446.wav
# Processing file: ../../segments/AVP_P11_kd_0447.wav
# Processing file: ../../segments/AVP_P11_kd_0448.wav
# Processing file: ../../segments/AVP_P11_kd_0449.wav
# Processing file: ../../segments/AVP_P11_kd_0450.wav
# Processing file: ../../segments/AVP_P11_kd_0451.wav
# Processing file: ../../segments/AVP_P11_kd_0452.wav
# Processing file: ../../segments/AVP_P11_kd_0453.wav
# Processing file: ../../segments/AVP_P11_kd_0454.wav
# Processing file: ../../segments/AVP_P11_kd_0455.wav
# Processing file: ../../segments/AVP_P11_kd_0456.wav
# Processing file: ../../segments/AVP_P11_kd_0457.wav
# Processing file: ../../segments/AVP_P11_kd_0458.wav
# Processing file: ../../segments/AVP_P11_kd_0459.wav
# Processing file: ../../segments/AVP_P11_kd_0460.wav
# Processing file: ../../segments/AVP_P11_kd_0461.wav
# Processing file: ../../segments/AVP_P11_sd_0462.wav
# Processing file: ../../segments/AVP_P11_sd_0463.wav
# Processing file: ../../segments/AVP_P11_sd_0464.wav
# Processing file: ../../segments/AVP_P11_sd_0465.wav
# Processing file: ../../segments/AVP_P11_sd_0466.wav
# Processing file: ../../segments/AVP_P11_sd_0467.wav
# Processed 3300 training samples...
# Processing file: ../../segments/AVP_P11_sd_0468.wav
# Processing file: ../../segments/AVP_P11_sd_0469.wav
# Processing file: ../../segments/AVP_P11_sd_0470.wav
# Processing file: ../../segments/AVP_P11_sd_0471.wav
# Processing file: ../../segments/AVP_P11_sd_0472.wav
# Processing file: ../../segments/AVP_P11_sd_0473.wav
# Processing file: ../../segments/AVP_P11_sd_0474.wav
# Processing file: ../../segments/AVP_P11_sd_0475.wav
# Processing file: ../../segments/AVP_P11_sd_0476.wav
# Processing file: ../../segments/AVP_P11_sd_0477.wav
# Processing file: ../../segments/AVP_P11_sd_0478.wav
# Processing file: ../../segments/AVP_P11_sd_0479.wav
# Processing file: ../../segments/AVP_P11_sd_0480.wav
# Processing file: ../../segments/AVP_P11_sd_0481.wav
# Processing file: ../../segments/AVP_P11_sd_0482.wav
# Processing file: ../../segments/AVP_P11_sd_0483.wav
# Processing file: ../../segments/AVP_P11_sd_0484.wav
# Processing file: ../../segments/AVP_P11_sd_0485.wav
# Processing file: ../../segments/AVP_P11_sd_0486.wav
# Processing file: ../../segments/AVP_P11_sd_0487.wav
# Processing file: ../../segments/AVP_P11_sd_0488.wav
# Processing file: ../../segments/AVP_P12_hhc_0489.wav
# Processing file: ../../segments/AVP_P12_hhc_0490.wav
# Processing file: ../../segments/AVP_P12_hhc_0491.wav
# Processing file: ../../segments/AVP_P12_hhc_0492.wav
# Processing file: ../../segments/AVP_P12_hhc_0493.wav
# Processing file: ../../segments/AVP_P12_hhc_0494.wav
# Processing file: ../../segments/AVP_P12_hhc_0495.wav
# Processing file: ../../segments/AVP_P12_hhc_0496.wav
# Processing file: ../../segments/AVP_P12_hhc_0497.wav
# Processing file: ../../segments/AVP_P12_hhc_0498.wav
# Processing file: ../../segments/AVP_P12_hhc_0499.wav
# Processing file: ../../segments/AVP_P12_hhc_0500.wav
# Processing file: ../../segments/AVP_P12_hhc_0501.wav
# Processing file: ../../segments/AVP_P12_hhc_0502.wav
# Processing file: ../../segments/AVP_P12_hhc_0503.wav
# Processing file: ../../segments/AVP_P12_hhc_0504.wav
# Processing file: ../../segments/AVP_P12_hhc_0505.wav
# Processing file: ../../segments/AVP_P12_hhc_0506.wav
# Processing file: ../../segments/AVP_P12_hhc_0507.wav
# Processing file: ../../segments/AVP_P12_hhc_0508.wav
# Processing file: ../../segments/AVP_P12_hhc_0509.wav
# Processing file: ../../segments/AVP_P12_hhc_0510.wav
# Processing file: ../../segments/AVP_P12_hhc_0511.wav
# Processing file: ../../segments/AVP_P12_hhc_0512.wav
# Processing file: ../../segments/AVP_P12_hhc_0513.wav
# Processing file: ../../segments/AVP_P12_hhc_0514.wav
# Processing file: ../../segments/AVP_P12_hho_0515.wav
# Processing file: ../../segments/AVP_P12_hho_0516.wav
# Processing file: ../../segments/AVP_P12_hho_0517.wav
# Processing file: ../../segments/AVP_P12_hho_0518.wav
# Processing file: ../../segments/AVP_P12_hho_0519.wav
# Processing file: ../../segments/AVP_P12_hho_0520.wav
# Processing file: ../../segments/AVP_P12_hho_0521.wav
# Processing file: ../../segments/AVP_P12_hho_0522.wav
# Processing file: ../../segments/AVP_P12_hho_0523.wav
# Processing file: ../../segments/AVP_P12_hho_0524.wav
# Processing file: ../../segments/AVP_P12_hho_0525.wav
# Processing file: ../../segments/AVP_P12_hho_0526.wav
# Processing file: ../../segments/AVP_P12_hho_0527.wav
# Processing file: ../../segments/AVP_P12_hho_0528.wav
# Processing file: ../../segments/AVP_P12_hho_0529.wav
# Processing file: ../../segments/AVP_P12_hho_0530.wav
# Processing file: ../../segments/AVP_P12_hho_0531.wav
# Processing file: ../../segments/AVP_P12_hho_0532.wav
# Processing file: ../../segments/AVP_P12_hho_0533.wav
# Processing file: ../../segments/AVP_P12_hho_0534.wav
# Processing file: ../../segments/AVP_P12_hho_0535.wav
# Processing file: ../../segments/AVP_P12_hho_0536.wav
# Processing file: ../../segments/AVP_P12_hho_0537.wav
# Processing file: ../../segments/AVP_P12_hho_0538.wav
# Processing file: ../../segments/AVP_P12_hho_0539.wav
# Processing file: ../../segments/AVP_P12_hho_0540.wav
# Processing file: ../../segments/AVP_P12_hho_0541.wav
# Processing file: ../../segments/AVP_P12_hho_0542.wav
# Processing file: ../../segments/AVP_P12_sd_0543.wav
# Processing file: ../../segments/AVP_P12_sd_0544.wav
# Processing file: ../../segments/AVP_P12_kd_0545.wav
# Processing file: ../../segments/AVP_P12_hho_0546.wav
# Processing file: ../../segments/AVP_P12_sd_0547.wav
# Processing file: ../../segments/AVP_P12_sd_0548.wav
# Processing file: ../../segments/AVP_P12_kd_0549.wav
# Processing file: ../../segments/AVP_P12_hho_0550.wav
# Processing file: ../../segments/AVP_P12_sd_0551.wav
# Processing file: ../../segments/AVP_P12_sd_0552.wav
# Processing file: ../../segments/AVP_P12_hhc_0553.wav
# Processing file: ../../segments/AVP_P12_hhc_0554.wav
# Processing file: ../../segments/AVP_P12_hhc_0555.wav
# Processing file: ../../segments/AVP_P12_hho_0556.wav
# Processing file: ../../segments/AVP_P12_hho_0557.wav
# Processing file: ../../segments/AVP_P12_kd_0558.wav
# Processing file: ../../segments/AVP_P12_kd_0559.wav
# Processing file: ../../segments/AVP_P12_hho_0560.wav
# Processing file: ../../segments/AVP_P12_hho_0561.wav
# Processing file: ../../segments/AVP_P12_kd_0562.wav
# Processing file: ../../segments/AVP_P12_hho_0563.wav
# Processing file: ../../segments/AVP_P12_hho_0564.wav
# Processing file: ../../segments/AVP_P12_kd_0565.wav
# Processing file: ../../segments/AVP_P12_hho_0566.wav
# Processing file: ../../segments/AVP_P12_hho_0567.wav
# Processed 4400 training samples...
# Processing file: ../../segments/AVP_P12_kd_0568.wav
# Processing file: ../../segments/AVP_P12_sd_0569.wav
# Processing file: ../../segments/AVP_P12_kd_0570.wav
# Processing file: ../../segments/AVP_P12_sd_0571.wav
# Processing file: ../../segments/AVP_P12_kd_0572.wav
# Processing file: ../../segments/AVP_P12_sd_0573.wav
# Processing file: ../../segments/AVP_P12_kd_0574.wav
# Processing file: ../../segments/AVP_P12_kd_0575.wav
# Processing file: ../../segments/AVP_P12_kd_0576.wav
# Processing file: ../../segments/AVP_P12_kd_0577.wav
# Processing file: ../../segments/AVP_P12_kd_0578.wav
# Processing file: ../../segments/AVP_P12_kd_0579.wav
# Processing file: ../../segments/AVP_P12_kd_0580.wav
# Processing file: ../../segments/AVP_P12_kd_0581.wav
# Processing file: ../../segments/AVP_P12_kd_0582.wav
# Processing file: ../../segments/AVP_P12_kd_0583.wav
# Processing file: ../../segments/AVP_P12_kd_0584.wav
# Processing file: ../../segments/AVP_P12_kd_0585.wav
# Processing file: ../../segments/AVP_P12_kd_0586.wav
# Processing file: ../../segments/AVP_P12_kd_0587.wav
# Processing file: ../../segments/AVP_P12_kd_0588.wav
# Processing file: ../../segments/AVP_P12_kd_0589.wav
# Processing file: ../../segments/AVP_P12_kd_0590.wav
# Processing file: ../../segments/AVP_P12_kd_0591.wav
# Processing file: ../../segments/AVP_P12_kd_0592.wav
# Processing file: ../../segments/AVP_P12_kd_0593.wav
# Processing file: ../../segments/AVP_P12_kd_0594.wav
# Processing file: ../../segments/AVP_P12_kd_0595.wav
# Processing file: ../../segments/AVP_P12_kd_0596.wav
# Processing file: ../../segments/AVP_P12_kd_0597.wav
# Processing file: ../../segments/AVP_P12_sd_0598.wav
# Processing file: ../../segments/AVP_P12_sd_0599.wav
# Processing file: ../../segments/AVP_P12_sd_0600.wav
# Processing file: ../../segments/AVP_P12_sd_0601.wav
# Processing file: ../../segments/AVP_P12_sd_0602.wav
# Processing file: ../../segments/AVP_P12_sd_0603.wav
# Processing file: ../../segments/AVP_P12_sd_0604.wav
# Processing file: ../../segments/AVP_P12_sd_0605.wav
# Processing file: ../../segments/AVP_P12_sd_0606.wav
# Processing file: ../../segments/AVP_P12_sd_0607.wav
# Processing file: ../../segments/AVP_P12_sd_0608.wav
# Processing file: ../../segments/AVP_P12_sd_0609.wav
# Processing file: ../../segments/AVP_P12_sd_0610.wav
# Processing file: ../../segments/AVP_P12_sd_0611.wav
# Processing file: ../../segments/AVP_P12_sd_0612.wav
# Processing file: ../../segments/AVP_P12_sd_0613.wav
# Processing file: ../../segments/AVP_P12_sd_0614.wav
# Processing file: ../../segments/AVP_P12_sd_0615.wav
# Processing file: ../../segments/AVP_P12_sd_0616.wav
# Processing file: ../../segments/AVP_P12_sd_0617.wav
# Processing file: ../../segments/AVP_P12_sd_0618.wav
# Processing file: ../../segments/AVP_P12_sd_0619.wav
# Processing file: ../../segments/AVP_P12_sd_0620.wav
# Processing file: ../../segments/AVP_P12_sd_0621.wav
# Processing file: ../../segments/AVP_P14_hhc_0756.wav
# Processing file: ../../segments/AVP_P14_hhc_0757.wav
# Processing file: ../../segments/AVP_P14_hhc_0758.wav
# Processing file: ../../segments/AVP_P14_hhc_0759.wav
# Processing file: ../../segments/AVP_P14_hhc_0760.wav
# Processing file: ../../segments/AVP_P14_hhc_0761.wav
# Processing file: ../../segments/AVP_P14_hhc_0762.wav
# Processing file: ../../segments/AVP_P14_hhc_0763.wav
# Processing file: ../../segments/AVP_P14_hhc_0764.wav
# Processing file: ../../segments/AVP_P14_hhc_0765.wav
# Processing file: ../../segments/AVP_P14_hhc_0766.wav
# Processing file: ../../segments/AVP_P14_hhc_0767.wav
# Processing file: ../../segments/AVP_P14_hhc_0768.wav
# Processing file: ../../segments/AVP_P14_hhc_0769.wav
# Processing file: ../../segments/AVP_P14_hhc_0770.wav
# Processing file: ../../segments/AVP_P14_hhc_0771.wav
# Processing file: ../../segments/AVP_P14_hhc_0772.wav
# Processing file: ../../segments/AVP_P14_hhc_0773.wav
# Processing file: ../../segments/AVP_P14_hhc_0774.wav
# Processing file: ../../segments/AVP_P14_hhc_0775.wav
# Processing file: ../../segments/AVP_P14_hhc_0776.wav
# Processing file: ../../segments/AVP_P14_hhc_0777.wav
# Processing file: ../../segments/AVP_P14_hhc_0778.wav
# Processing file: ../../segments/AVP_P14_hhc_0779.wav
# Processing file: ../../segments/AVP_P14_hhc_0780.wav
# Processing file: ../../segments/AVP_P14_hhc_0781.wav
# Processing file: ../../segments/AVP_P14_hho_0782.wav
# Processing file: ../../segments/AVP_P14_hho_0783.wav
# Processing file: ../../segments/AVP_P14_hho_0784.wav
# Processing file: ../../segments/AVP_P14_hho_0785.wav
# Processing file: ../../segments/AVP_P14_hho_0786.wav
# Processing file: ../../segments/AVP_P14_hho_0787.wav
# Processing file: ../../segments/AVP_P14_hho_0788.wav
# Processing file: ../../segments/AVP_P14_hho_0789.wav
# Processing file: ../../segments/AVP_P14_hho_0790.wav
# Processing file: ../../segments/AVP_P14_hho_0791.wav
# Processing file: ../../segments/AVP_P14_hho_0792.wav
# Processing file: ../../segments/AVP_P14_hho_0793.wav
# Processing file: ../../segments/AVP_P14_hho_0794.wav
# Processing file: ../../segments/AVP_P14_hho_0795.wav
# Processing file: ../../segments/AVP_P14_hho_0796.wav
# Processing file: ../../segments/AVP_P14_hho_0797.wav
# Processing file: ../../segments/AVP_P14_hho_0798.wav
# Processing file: ../../segments/AVP_P14_hho_0799.wav
# Processing file: ../../segments/AVP_P14_hho_0800.wav
# Processing file: ../../segments/AVP_P14_hho_0801.wav
# Processed 5500 training samples...
# Processing file: ../../segments/AVP_P14_hho_0802.wav
# Processing file: ../../segments/AVP_P14_hho_0803.wav
# Processing file: ../../segments/AVP_P14_hho_0804.wav
# Processing file: ../../segments/AVP_P14_hho_0805.wav
# Processing file: ../../segments/AVP_P14_hho_0806.wav
# Processing file: ../../segments/AVP_P14_hho_0807.wav
# Processing file: ../../segments/AVP_P14_hho_0808.wav
# Processing file: ../../segments/AVP_P14_kd_0809.wav
# Processing file: ../../segments/AVP_P14_hhc_0810.wav
# Processing file: ../../segments/AVP_P14_sd_0811.wav
# Processing file: ../../segments/AVP_P14_kd_0812.wav
# Processing file: ../../segments/AVP_P14_hhc_0813.wav
# Processing file: ../../segments/AVP_P14_sd_0814.wav
# Processing file: ../../segments/AVP_P14_kd_0815.wav
# Processing file: ../../segments/AVP_P14_kd_0816.wav
# Processing file: ../../segments/AVP_P14_hhc_0817.wav
# Processing file: ../../segments/AVP_P14_sd_0818.wav
# Processing file: ../../segments/AVP_P14_hhc_0819.wav
# Processing file: ../../segments/AVP_P14_sd_0820.wav
# Processing file: ../../segments/AVP_P14_kd_0821.wav
# Processing file: ../../segments/AVP_P14_kd_0822.wav
# Processing file: ../../segments/AVP_P14_hhc_0823.wav
# Processing file: ../../segments/AVP_P14_sd_0824.wav
# Processing file: ../../segments/AVP_P14_kd_0825.wav
# Processing file: ../../segments/AVP_P14_hhc_0826.wav
# Processing file: ../../segments/AVP_P14_sd_0827.wav
# Processing file: ../../segments/AVP_P14_kd_0828.wav
# Processing file: ../../segments/AVP_P14_kd_0829.wav
# Processing file: ../../segments/AVP_P14_hhc_0830.wav
# Processing file: ../../segments/AVP_P14_sd_0831.wav
# Processing file: ../../segments/AVP_P14_hhc_0832.wav
# Processing file: ../../segments/AVP_P14_sd_0833.wav
# Processing file: ../../segments/AVP_P14_kd_0834.wav
# Processing file: ../../segments/AVP_P14_kd_0835.wav
# Processing file: ../../segments/AVP_P14_hhc_0836.wav
# Processing file: ../../segments/AVP_P14_sd_0837.wav
# Processing file: ../../segments/AVP_P14_kd_0838.wav
# Processing file: ../../segments/AVP_P14_hhc_0839.wav
# Processing file: ../../segments/AVP_P14_sd_0840.wav
# Processing file: ../../segments/AVP_P14_kd_0841.wav
# Processing file: ../../segments/AVP_P14_kd_0842.wav
# Processing file: ../../segments/AVP_P14_hhc_0843.wav
# Processing file: ../../segments/AVP_P14_sd_0844.wav
# Processing file: ../../segments/AVP_P14_hhc_0845.wav
# Processing file: ../../segments/AVP_P14_sd_0846.wav
# Processing file: ../../segments/AVP_P14_kd_0847.wav
# Processing file: ../../segments/AVP_P14_kd_0848.wav
# Processing file: ../../segments/AVP_P14_hhc_0849.wav
# Processing file: ../../segments/AVP_P14_sd_0850.wav
# Processing file: ../../segments/AVP_P14_kd_0851.wav
# Processing file: ../../segments/AVP_P14_hhc_0852.wav
# Processing file: ../../segments/AVP_P14_sd_0853.wav
# Processing file: ../../segments/AVP_P14_kd_0854.wav
# Processing file: ../../segments/AVP_P14_kd_0855.wav
# Processing file: ../../segments/AVP_P14_hhc_0856.wav
# Processing file: ../../segments/AVP_P14_sd_0857.wav
# Processing file: ../../segments/AVP_P14_hhc_0858.wav
# Processing file: ../../segments/AVP_P14_sd_0859.wav
# Processing file: ../../segments/AVP_P14_kd_0860.wav
# Processing file: ../../segments/AVP_P14_kd_0861.wav
# Processing file: ../../segments/AVP_P14_kd_0862.wav
# Processing file: ../../segments/AVP_P14_kd_0863.wav
# Processing file: ../../segments/AVP_P14_kd_0864.wav
# Processing file: ../../segments/AVP_P14_kd_0865.wav
# Processing file: ../../segments/AVP_P14_kd_0866.wav
# Processing file: ../../segments/AVP_P14_kd_0867.wav
# Processing file: ../../segments/AVP_P14_kd_0868.wav
# Processing file: ../../segments/AVP_P14_kd_0869.wav
# Processing file: ../../segments/AVP_P14_kd_0870.wav
# Processing file: ../../segments/AVP_P14_kd_0871.wav
# Processing file: ../../segments/AVP_P14_kd_0872.wav
# Processing file: ../../segments/AVP_P14_kd_0873.wav
# Processing file: ../../segments/AVP_P14_kd_0874.wav
# Processing file: ../../segments/AVP_P14_kd_0875.wav
# Processing file: ../../segments/AVP_P14_kd_0876.wav
# Processing file: ../../segments/AVP_P14_kd_0877.wav
# Processing file: ../../segments/AVP_P14_kd_0878.wav
# Processing file: ../../segments/AVP_P14_kd_0879.wav
# Processing file: ../../segments/AVP_P14_kd_0880.wav
# Processing file: ../../segments/AVP_P14_kd_0881.wav
# Processing file: ../../segments/AVP_P14_kd_0882.wav
# Processing file: ../../segments/AVP_P14_kd_0883.wav
# Processing file: ../../segments/AVP_P14_kd_0884.wav
# Processing file: ../../segments/AVP_P14_kd_0885.wav
# Processing file: ../../segments/AVP_P14_kd_0886.wav
# Processing file: ../../segments/AVP_P14_kd_0887.wav
# Processing file: ../../segments/AVP_P14_sd_0888.wav
# Processing file: ../../segments/AVP_P14_sd_0889.wav
# Processing file: ../../segments/AVP_P14_sd_0890.wav
# Processing file: ../../segments/AVP_P14_sd_0891.wav
# Processing file: ../../segments/AVP_P14_sd_0892.wav
# Processing file: ../../segments/AVP_P14_sd_0893.wav
# Processing file: ../../segments/AVP_P14_sd_0894.wav
# Processing file: ../../segments/AVP_P14_sd_0895.wav
# Processing file: ../../segments/AVP_P14_sd_0896.wav
# Processing file: ../../segments/AVP_P14_sd_0897.wav
# Processing file: ../../segments/AVP_P14_sd_0898.wav
# Processing file: ../../segments/AVP_P14_sd_0899.wav
# Processing file: ../../segments/AVP_P14_sd_0900.wav
# Processing file: ../../segments/AVP_P14_sd_0901.wav
# Processed 6600 training samples...
# Processing file: ../../segments/AVP_P14_sd_0902.wav
# Processing file: ../../segments/AVP_P14_sd_0903.wav
# Processing file: ../../segments/AVP_P14_sd_0904.wav
# Processing file: ../../segments/AVP_P14_sd_0905.wav
# Processing file: ../../segments/AVP_P14_sd_0906.wav
# Processing file: ../../segments/AVP_P14_sd_0907.wav
# Processing file: ../../segments/AVP_P14_sd_0908.wav
# Processing file: ../../segments/AVP_P14_sd_0909.wav
# Processing file: ../../segments/AVP_P14_sd_0910.wav
# Processing file: ../../segments/AVP_P14_sd_0911.wav
# Processing file: ../../segments/AVP_P14_sd_0912.wav
# Processing file: ../../segments/AVP_P14_sd_0913.wav
# Processing file: ../../segments/AVP_P14_sd_0914.wav
# Processing file: ../../segments/AVP_P15_hhc_0915.wav
# Processing file: ../../segments/AVP_P15_hhc_0916.wav
# Processing file: ../../segments/AVP_P15_hhc_0917.wav
# Processing file: ../../segments/AVP_P15_hhc_0918.wav
# Processing file: ../../segments/AVP_P15_hhc_0919.wav
# Processing file: ../../segments/AVP_P15_hhc_0920.wav
# Processing file: ../../segments/AVP_P15_hhc_0921.wav
# Processing file: ../../segments/AVP_P15_hhc_0922.wav
# Processing file: ../../segments/AVP_P15_hhc_0923.wav
# Processing file: ../../segments/AVP_P15_hhc_0924.wav
# Processing file: ../../segments/AVP_P15_hhc_0925.wav
# Processing file: ../../segments/AVP_P15_hhc_0926.wav
# Processing file: ../../segments/AVP_P15_hhc_0927.wav
# Processing file: ../../segments/AVP_P15_hhc_0928.wav
# Processing file: ../../segments/AVP_P15_hhc_0929.wav
# Processing file: ../../segments/AVP_P15_hhc_0930.wav
# Processing file: ../../segments/AVP_P15_hhc_0931.wav
# Processing file: ../../segments/AVP_P15_hhc_0932.wav
# Processing file: ../../segments/AVP_P15_hhc_0933.wav
# Processing file: ../../segments/AVP_P15_hhc_0934.wav
# Processing file: ../../segments/AVP_P15_hhc_0935.wav
# Processing file: ../../segments/AVP_P15_hhc_0936.wav
# Processing file: ../../segments/AVP_P15_hhc_0937.wav
# Processing file: ../../segments/AVP_P15_hhc_0938.wav
# Processing file: ../../segments/AVP_P15_hhc_0939.wav
# Processing file: ../../segments/AVP_P15_hhc_0940.wav
# Processing file: ../../segments/AVP_P15_hhc_0941.wav
# Processing file: ../../segments/AVP_P15_hhc_0942.wav
# Processing file: ../../segments/AVP_P15_hhc_0943.wav
# Processing file: ../../segments/AVP_P15_hhc_0944.wav
# Processing file: ../../segments/AVP_P15_hho_0945.wav
# Processing file: ../../segments/AVP_P15_hho_0946.wav
# Processing file: ../../segments/AVP_P15_hho_0947.wav
# Processing file: ../../segments/AVP_P15_hho_0948.wav
# Processing file: ../../segments/AVP_P15_hho_0949.wav
# Processing file: ../../segments/AVP_P15_hho_0950.wav
# Processing file: ../../segments/AVP_P15_hho_0951.wav
# Processing file: ../../segments/AVP_P15_hho_0952.wav
# Processing file: ../../segments/AVP_P15_hho_0953.wav
# Processing file: ../../segments/AVP_P15_hho_0954.wav
# Processing file: ../../segments/AVP_P15_hho_0955.wav
# Processing file: ../../segments/AVP_P15_hho_0956.wav
# Processing file: ../../segments/AVP_P15_hho_0957.wav
# Processing file: ../../segments/AVP_P15_hho_0958.wav
# Processing file: ../../segments/AVP_P15_hho_0959.wav
# Processing file: ../../segments/AVP_P15_hho_0960.wav
# Processing file: ../../segments/AVP_P15_hho_0961.wav
# Processing file: ../../segments/AVP_P15_hho_0962.wav
# Processing file: ../../segments/AVP_P15_hho_0963.wav
# Processing file: ../../segments/AVP_P15_hho_0964.wav
# Processing file: ../../segments/AVP_P15_hho_0965.wav
# Processing file: ../../segments/AVP_P15_hho_0966.wav
# Processing file: ../../segments/AVP_P15_hho_0967.wav
# Processing file: ../../segments/AVP_P15_hho_0968.wav
# Processing file: ../../segments/AVP_P15_hho_0969.wav
# Processing file: ../../segments/AVP_P15_hho_0970.wav
# Processing file: ../../segments/AVP_P15_hho_0971.wav
# Processing file: ../../segments/AVP_P15_hho_0972.wav
# Processing file: ../../segments/AVP_P15_hho_0973.wav
# Processing file: ../../segments/AVP_P15_hho_0974.wav
# Processing file: ../../segments/AVP_P15_kd_0975.wav
# Processing file: ../../segments/AVP_P15_kd_0976.wav
# Processing file: ../../segments/AVP_P15_hho_0977.wav
# Processing file: ../../segments/AVP_P15_hho_0978.wav
# Processing file: ../../segments/AVP_P15_kd_0979.wav
# Processing file: ../../segments/AVP_P15_hhc_0980.wav
# Processing file: ../../segments/AVP_P15_sd_0981.wav
# Processing file: ../../segments/AVP_P15_kd_0982.wav
# Processing file: ../../segments/AVP_P15_kd_0983.wav
# Processing file: ../../segments/AVP_P15_hho_0984.wav
# Processing file: ../../segments/AVP_P15_hhc_0985.wav
# Processing file: ../../segments/AVP_P15_hhc_0986.wav
# Processing file: ../../segments/AVP_P15_hhc_0987.wav
# Processing file: ../../segments/AVP_P15_hhc_0988.wav
# Processing file: ../../segments/AVP_P15_hhc_0989.wav
# Processing file: ../../segments/AVP_P15_hhc_0990.wav
# Processing file: ../../segments/AVP_P15_hhc_0991.wav
# Processing file: ../../segments/AVP_P15_hhc_0992.wav
# Processing file: ../../segments/AVP_P15_hhc_0993.wav
# Processing file: ../../segments/AVP_P15_hhc_0994.wav
# Processing file: ../../segments/AVP_P15_hhc_0995.wav
# Processing file: ../../segments/AVP_P15_hhc_0996.wav
# Processing file: ../../segments/AVP_P15_hho_0997.wav
# Processing file: ../../segments/AVP_P15_kd_0998.wav
# Processing file: ../../segments/AVP_P15_hhc_0999.wav
# Processing file: ../../segments/AVP_P15_sd_1000.wav
# Processing file: ../../segments/AVP_P15_kd_1001.wav
# Processed 7700 training samples...
# Processing file: ../../segments/AVP_P15_kd_1002.wav
# Processing file: ../../segments/AVP_P15_kd_1003.wav
# Processing file: ../../segments/AVP_P15_kd_1004.wav
# Processing file: ../../segments/AVP_P15_kd_1005.wav
# Processing file: ../../segments/AVP_P15_kd_1006.wav
# Processing file: ../../segments/AVP_P15_kd_1007.wav
# Processing file: ../../segments/AVP_P15_kd_1008.wav
# Processing file: ../../segments/AVP_P15_kd_1009.wav
# Processing file: ../../segments/AVP_P15_kd_1010.wav
# Processing file: ../../segments/AVP_P15_kd_1011.wav
# Processing file: ../../segments/AVP_P15_kd_1012.wav
# Processing file: ../../segments/AVP_P15_kd_1013.wav
# Processing file: ../../segments/AVP_P15_kd_1014.wav
# Processing file: ../../segments/AVP_P15_kd_1015.wav
# Processing file: ../../segments/AVP_P15_kd_1016.wav
# Processing file: ../../segments/AVP_P15_kd_1017.wav
# Processing file: ../../segments/AVP_P15_kd_1018.wav
# Processing file: ../../segments/AVP_P15_kd_1019.wav
# Processing file: ../../segments/AVP_P15_kd_1020.wav
# Processing file: ../../segments/AVP_P15_kd_1021.wav
# Processing file: ../../segments/AVP_P15_kd_1022.wav
# Processing file: ../../segments/AVP_P15_kd_1023.wav
# Processing file: ../../segments/AVP_P15_kd_1024.wav
# Processing file: ../../segments/AVP_P15_kd_1025.wav
# Processing file: ../../segments/AVP_P15_kd_1026.wav
# Processing file: ../../segments/AVP_P15_kd_1027.wav
# Processing file: ../../segments/AVP_P15_kd_1028.wav
# Processing file: ../../segments/AVP_P15_kd_1029.wav
# Processing file: ../../segments/AVP_P15_kd_1030.wav
# Processing file: ../../segments/AVP_P15_kd_1031.wav
# Processing file: ../../segments/AVP_P15_sd_1032.wav
# Processing file: ../../segments/AVP_P15_sd_1033.wav
# Processing file: ../../segments/AVP_P15_sd_1034.wav
# Processing file: ../../segments/AVP_P15_sd_1035.wav
# Processing file: ../../segments/AVP_P15_sd_1036.wav
# Processing file: ../../segments/AVP_P15_sd_1037.wav
# Processing file: ../../segments/AVP_P15_sd_1038.wav
# Processing file: ../../segments/AVP_P15_sd_1039.wav
# Processing file: ../../segments/AVP_P15_sd_1040.wav
# Processing file: ../../segments/AVP_P15_sd_1041.wav
# Processing file: ../../segments/AVP_P15_sd_1042.wav
# Processing file: ../../segments/AVP_P15_sd_1043.wav
# Processing file: ../../segments/AVP_P15_sd_1044.wav
# Processing file: ../../segments/AVP_P15_sd_1045.wav
# Processing file: ../../segments/AVP_P15_sd_1046.wav
# Processing file: ../../segments/AVP_P15_sd_1047.wav
# Processing file: ../../segments/AVP_P15_sd_1048.wav
# Processing file: ../../segments/AVP_P15_sd_1049.wav
# Processing file: ../../segments/AVP_P15_sd_1050.wav
# Processing file: ../../segments/AVP_P15_sd_1051.wav
# Processing file: ../../segments/AVP_P15_sd_1052.wav
# Processing file: ../../segments/AVP_P15_sd_1053.wav
# Processing file: ../../segments/AVP_P15_sd_1054.wav
# Processing file: ../../segments/AVP_P15_sd_1055.wav
# Processing file: ../../segments/AVP_P15_sd_1056.wav
# Processing file: ../../segments/AVP_P15_sd_1057.wav
# Processing file: ../../segments/AVP_P15_sd_1058.wav
# Processing file: ../../segments/AVP_P15_sd_1059.wav
# Processing file: ../../segments/AVP_P15_sd_1060.wav
# Processing file: ../../segments/AVP_P15_sd_1061.wav
# Processing file: ../../segments/AVP_P15_sd_1062.wav
# Processing file: ../../segments/AVP_P15_sd_1063.wav
# Processing file: ../../segments/AVP_P15_sd_1064.wav
# Processing file: ../../segments/AVP_P15_sd_1065.wav
# Processing file: ../../segments/AVP_P17_hhc_1247.wav
# Processing file: ../../segments/AVP_P17_hhc_1248.wav
# Processing file: ../../segments/AVP_P17_hhc_1249.wav
# Processing file: ../../segments/AVP_P17_hhc_1250.wav
# Processing file: ../../segments/AVP_P17_hhc_1251.wav
# Processing file: ../../segments/AVP_P17_hhc_1252.wav
# Processing file: ../../segments/AVP_P17_hhc_1253.wav
# Processing file: ../../segments/AVP_P17_hhc_1254.wav
# Processing file: ../../segments/AVP_P17_hhc_1255.wav
# Processing file: ../../segments/AVP_P17_hhc_1256.wav
# Processing file: ../../segments/AVP_P17_hhc_1257.wav
# Processing file: ../../segments/AVP_P17_hhc_1258.wav
# Processing file: ../../segments/AVP_P17_hhc_1259.wav
# Processing file: ../../segments/AVP_P17_hhc_1260.wav
# Processing file: ../../segments/AVP_P17_hhc_1261.wav
# Processing file: ../../segments/AVP_P17_hhc_1262.wav
# Processing file: ../../segments/AVP_P17_hhc_1263.wav
# Processing file: ../../segments/AVP_P17_hhc_1264.wav
# Processing file: ../../segments/AVP_P17_hhc_1265.wav
# Processing file: ../../segments/AVP_P17_hhc_1266.wav
# Processing file: ../../segments/AVP_P17_hhc_1267.wav
# Processing file: ../../segments/AVP_P17_hhc_1268.wav
# Processing file: ../../segments/AVP_P17_hhc_1269.wav
# Processing file: ../../segments/AVP_P17_hhc_1270.wav
# Processing file: ../../segments/AVP_P17_hho_1271.wav
# Processing file: ../../segments/AVP_P17_hho_1272.wav
# Processing file: ../../segments/AVP_P17_hho_1273.wav
# Processing file: ../../segments/AVP_P17_hho_1274.wav
# Processing file: ../../segments/AVP_P17_hho_1275.wav
# Processing file: ../../segments/AVP_P17_hho_1276.wav
# Processing file: ../../segments/AVP_P17_hho_1277.wav
# Processing file: ../../segments/AVP_P17_hho_1278.wav
# Processing file: ../../segments/AVP_P17_hho_1279.wav
# Processing file: ../../segments/AVP_P17_hho_1280.wav
# Processing file: ../../segments/AVP_P17_hho_1281.wav
# Processing file: ../../segments/AVP_P17_hho_1282.wav
# Processed 8800 training samples...
# Processing file: ../../segments/AVP_P17_hho_1283.wav
# Processing file: ../../segments/AVP_P17_hho_1284.wav
# Processing file: ../../segments/AVP_P17_hho_1285.wav
# Processing file: ../../segments/AVP_P17_hho_1286.wav
# Processing file: ../../segments/AVP_P17_hho_1287.wav
# Processing file: ../../segments/AVP_P17_hho_1288.wav
# Processing file: ../../segments/AVP_P17_hho_1289.wav
# Processing file: ../../segments/AVP_P17_hho_1290.wav
# Processing file: ../../segments/AVP_P17_hho_1291.wav
# Processing file: ../../segments/AVP_P17_hho_1292.wav
# Processing file: ../../segments/AVP_P17_hho_1293.wav
# Processing file: ../../segments/AVP_P17_hho_1294.wav
# Processing file: ../../segments/AVP_P17_hho_1295.wav
# Processing file: ../../segments/AVP_P17_hho_1296.wav
# Processing file: ../../segments/AVP_P17_hho_1297.wav
# Processing file: ../../segments/AVP_P17_hho_1298.wav
# Processing file: ../../segments/AVP_P17_hho_1299.wav
# Processing file: ../../segments/AVP_P17_hho_1300.wav
# Processing file: ../../segments/AVP_P17_hho_1301.wav
# Processing file: ../../segments/AVP_P17_hho_1302.wav
# Processing file: ../../segments/AVP_P17_hho_1303.wav
# Processing file: ../../segments/AVP_P17_hho_1304.wav
# Processing file: ../../segments/AVP_P17_hho_1305.wav
# Processing file: ../../segments/AVP_P17_hho_1306.wav
# Processing file: ../../segments/AVP_P17_hho_1307.wav
# Processing file: ../../segments/AVP_P17_hho_1308.wav
# Processing file: ../../segments/AVP_P17_hho_1309.wav
# Processing file: ../../segments/AVP_P17_kd_1310.wav
# Processing file: ../../segments/AVP_P17_hho_1311.wav
# Processing file: ../../segments/AVP_P17_kd_1312.wav
# Processing file: ../../segments/AVP_P17_kd_1313.wav
# Processing file: ../../segments/AVP_P17_kd_1314.wav
# Processing file: ../../segments/AVP_P17_hho_1315.wav
# Processing file: ../../segments/AVP_P17_kd_1316.wav
# Processing file: ../../segments/AVP_P17_kd_1317.wav
# Processing file: ../../segments/AVP_P17_kd_1318.wav
# Processing file: ../../segments/AVP_P17_hho_1319.wav
# Processing file: ../../segments/AVP_P17_kd_1320.wav
# Processing file: ../../segments/AVP_P17_kd_1321.wav
# Processing file: ../../segments/AVP_P17_kd_1322.wav
# Processing file: ../../segments/AVP_P17_hho_1323.wav
# Processing file: ../../segments/AVP_P17_kd_1324.wav
# Processing file: ../../segments/AVP_P17_kd_1325.wav
# Processing file: ../../segments/AVP_P17_hho_1326.wav
# Processing file: ../../segments/AVP_P17_kd_1327.wav
# Processing file: ../../segments/AVP_P17_kd_1328.wav
# Processing file: ../../segments/AVP_P17_kd_1329.wav
# Processing file: ../../segments/AVP_P17_hho_1330.wav
# Processing file: ../../segments/AVP_P17_hhc_1331.wav
# Processing file: ../../segments/AVP_P17_kd_1332.wav
# Processing file: ../../segments/AVP_P17_kd_1333.wav
# Processing file: ../../segments/AVP_P17_sd_1334.wav
# Processing file: ../../segments/AVP_P17_kd_1335.wav
# Processing file: ../../segments/AVP_P17_kd_1336.wav
# Processing file: ../../segments/AVP_P17_kd_1337.wav
# Processing file: ../../segments/AVP_P17_kd_1338.wav
# Processing file: ../../segments/AVP_P17_hho_1339.wav
# Processing file: ../../segments/AVP_P17_kd_1340.wav
# Processing file: ../../segments/AVP_P17_kd_1341.wav
# Processing file: ../../segments/AVP_P17_kd_1342.wav
# Processing file: ../../segments/AVP_P17_kd_1343.wav
# Processing file: ../../segments/AVP_P17_kd_1344.wav
# Processing file: ../../segments/AVP_P17_kd_1345.wav
# Processing file: ../../segments/AVP_P17_kd_1346.wav
# Processing file: ../../segments/AVP_P17_kd_1347.wav
# Processing file: ../../segments/AVP_P17_kd_1348.wav
# Processing file: ../../segments/AVP_P17_kd_1349.wav
# Processing file: ../../segments/AVP_P17_kd_1350.wav
# Processing file: ../../segments/AVP_P17_kd_1351.wav
# Processing file: ../../segments/AVP_P17_kd_1352.wav
# Processing file: ../../segments/AVP_P17_kd_1353.wav
# Processing file: ../../segments/AVP_P17_kd_1354.wav
# Processing file: ../../segments/AVP_P17_kd_1355.wav
# Processing file: ../../segments/AVP_P17_kd_1356.wav
# Processing file: ../../segments/AVP_P17_kd_1357.wav
# Processing file: ../../segments/AVP_P17_kd_1358.wav
# Processing file: ../../segments/AVP_P17_kd_1359.wav
# Processing file: ../../segments/AVP_P17_kd_1360.wav
# Processing file: ../../segments/AVP_P17_kd_1361.wav
# Processing file: ../../segments/AVP_P17_kd_1362.wav
# Processing file: ../../segments/AVP_P17_kd_1363.wav
# Processing file: ../../segments/AVP_P17_kd_1364.wav
# Processing file: ../../segments/AVP_P17_kd_1365.wav
# ...
# Processing file: ../../segments/AVP_P9_sd_4856.wav
# Processing file: ../../segments/AVP_P9_sd_4857.wav
# Processing file: ../../segments/AVP_P9_sd_4858.wav
# Processing file: ../../segments/AVP_P9_sd_4859.wav
# Processing file: ../../segments/AVP_P9_sd_4860.wav
# Processed 42900 training samples...
# Processing file: ../../segments/AVP_P9_sd_4861.wav
# Processing file: ../../segments/AVP_P9_sd_4862.wav
# Processing file: ../../segments/AVP_P9_sd_4863.wav
# Processing file: ../../segments/AVP_P9_sd_4864.wav
# Processing file: ../../segments/AVP_P9_sd_4865.wav
# Processing file: ../../segments/AVP_P9_sd_4866.wav
# Processing file: ../../segments/AVP_P9_sd_4867.wav
# Processing file: ../../segments/AVP_P9_sd_4868.wav
# Processing file: ../../segments/AVP_P9_sd_4869.wav
# Processing file: ../../segments/AVP_P9_sd_4870.wav
# Processing file: ../../segments/AVP_P9_sd_4871.wav
# Processing file: ../../segments/AVP_P9_sd_4872.wav
# Processing file: ../../segments/LVT_AFRP_kd_4873.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4874.wav
# Processing file: ../../segments/LVT_AFRP_kd_4875.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4876.wav
# Processing file: ../../segments/LVT_AFRP_sd_4877.wav
# Processing file: ../../segments/LVT_AFRP_kd_4878.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4879.wav
# Processing file: ../../segments/LVT_AFRP_kd_4880.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4881.wav
# Processing file: ../../segments/LVT_AFRP_sd_4882.wav
# Processing file: ../../segments/LVT_AFRP_kd_4883.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4884.wav
# Processing file: ../../segments/LVT_AFRP_kd_4885.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4886.wav
# Processing file: ../../segments/LVT_AFRP_sd_4887.wav
# Processing file: ../../segments/LVT_AFRP_kd_4888.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4889.wav
# Processing file: ../../segments/LVT_AFRP_kd_4890.wav
# Processing file: ../../segments/LVT_AFRP_hhc_4891.wav
# Processing file: ../../segments/LVT_AFRP_sd_4892.wav
# Processing file: ../../segments/LVT_AZiP_kd_4893.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4894.wav
# Processing file: ../../segments/LVT_AZiP_kd_4895.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4896.wav
# Processing file: ../../segments/LVT_AZiP_sd_4897.wav
# Processing file: ../../segments/LVT_AZiP_kd_4898.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4899.wav
# Processing file: ../../segments/LVT_AZiP_kd_4900.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4901.wav
# Processing file: ../../segments/LVT_AZiP_sd_4902.wav
# Processing file: ../../segments/LVT_AZiP_kd_4903.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4904.wav
# Processing file: ../../segments/LVT_AZiP_kd_4905.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4906.wav
# Processing file: ../../segments/LVT_AZiP_sd_4907.wav
# Processing file: ../../segments/LVT_AZiP_kd_4908.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4909.wav
# Processing file: ../../segments/LVT_AZiP_kd_4910.wav
# Processing file: ../../segments/LVT_AZiP_hhc_4911.wav
# Processing file: ../../segments/LVT_AZiP_sd_4912.wav
# Processing file: ../../segments/LVT_BeaP_kd_4913.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4914.wav
# Processing file: ../../segments/LVT_BeaP_kd_4915.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4916.wav
# Processing file: ../../segments/LVT_BeaP_sd_4917.wav
# Processing file: ../../segments/LVT_BeaP_kd_4918.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4919.wav
# Processing file: ../../segments/LVT_BeaP_kd_4920.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4921.wav
# Processing file: ../../segments/LVT_BeaP_sd_4922.wav
# Processing file: ../../segments/LVT_BeaP_kd_4923.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4924.wav
# Processing file: ../../segments/LVT_BeaP_kd_4925.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4926.wav
# Processing file: ../../segments/LVT_BeaP_sd_4927.wav
# Processing file: ../../segments/LVT_BeaP_kd_4928.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4929.wav
# Processing file: ../../segments/LVT_BeaP_kd_4930.wav
# Processing file: ../../segments/LVT_BeaP_hhc_4931.wav
# Processing file: ../../segments/LVT_BeaP_sd_4932.wav
# Processing file: ../../segments/LVT_BicP_kd_4933.wav
# Processing file: ../../segments/LVT_BicP_hhc_4934.wav
# Processing file: ../../segments/LVT_BicP_kd_4935.wav
# Processing file: ../../segments/LVT_BicP_hhc_4936.wav
# Processing file: ../../segments/LVT_BicP_sd_4937.wav
# Processing file: ../../segments/LVT_BicP_kd_4938.wav
# Processing file: ../../segments/LVT_BicP_hhc_4939.wav
# Processing file: ../../segments/LVT_BicP_kd_4940.wav
# Processing file: ../../segments/LVT_BicP_hhc_4941.wav
# Processing file: ../../segments/LVT_BicP_sd_4942.wav
# Processing file: ../../segments/LVT_BicP_kd_4943.wav
# Processing file: ../../segments/LVT_BicP_hhc_4944.wav
# Processing file: ../../segments/LVT_BicP_kd_4945.wav
# Processing file: ../../segments/LVT_BicP_hhc_4946.wav
# Processing file: ../../segments/LVT_BicP_sd_4947.wav
# Processing file: ../../segments/LVT_BicP_kd_4948.wav
# Processing file: ../../segments/LVT_BicP_hhc_4949.wav
# Processing file: ../../segments/LVT_BicP_kd_4950.wav
# Processing file: ../../segments/LVT_BicP_hhc_4951.wav
# Processing file: ../../segments/LVT_BicP_sd_4952.wav
# Processing file: ../../segments/LVT_CavP_kd_4973.wav
# Processing file: ../../segments/LVT_CavP_hhc_4974.wav
# Processing file: ../../segments/LVT_CavP_kd_4975.wav
# Processing file: ../../segments/LVT_CavP_hhc_4976.wav
# Processing file: ../../segments/LVT_CavP_sd_4977.wav
# Processing file: ../../segments/LVT_CavP_kd_4978.wav
# Processing file: ../../segments/LVT_CavP_hhc_4979.wav
# Processing file: ../../segments/LVT_CavP_kd_4980.wav
# Processed 44000 training samples...
# Processing file: ../../segments/LVT_CavP_hhc_4981.wav
# Processing file: ../../segments/LVT_CavP_sd_4982.wav
# Processing file: ../../segments/LVT_CavP_kd_4983.wav
# Processing file: ../../segments/LVT_CavP_hhc_4984.wav
# Processing file: ../../segments/LVT_CavP_kd_4985.wav
# Processing file: ../../segments/LVT_CavP_hhc_4986.wav
# Processing file: ../../segments/LVT_CavP_sd_4987.wav
# Processing file: ../../segments/LVT_CavP_kd_4988.wav
# Processing file: ../../segments/LVT_CavP_hhc_4989.wav
# Processing file: ../../segments/LVT_CavP_kd_4990.wav
# Processing file: ../../segments/LVT_CavP_hhc_4991.wav
# Processing file: ../../segments/LVT_CavP_sd_4992.wav
# Processing file: ../../segments/LVT_CraP_kd_4993.wav
# Processing file: ../../segments/LVT_CraP_hhc_4994.wav
# Processing file: ../../segments/LVT_CraP_kd_4995.wav
# Processing file: ../../segments/LVT_CraP_hhc_4996.wav
# Processing file: ../../segments/LVT_CraP_sd_4997.wav
# Processing file: ../../segments/LVT_CraP_kd_4998.wav
# Processing file: ../../segments/LVT_CraP_hhc_4999.wav
# Processing file: ../../segments/LVT_CraP_kd_5000.wav
# Processing file: ../../segments/LVT_CraP_hhc_5001.wav
# Processing file: ../../segments/LVT_CraP_sd_5002.wav
# Processing file: ../../segments/LVT_CraP_kd_5003.wav
# Processing file: ../../segments/LVT_CraP_hhc_5004.wav
# Processing file: ../../segments/LVT_CraP_kd_5005.wav
# Processing file: ../../segments/LVT_CraP_hhc_5006.wav
# Processing file: ../../segments/LVT_CraP_sd_5007.wav
# Processing file: ../../segments/LVT_CraP_kd_5008.wav
# Processing file: ../../segments/LVT_CraP_hhc_5009.wav
# Processing file: ../../segments/LVT_CraP_kd_5010.wav
# Processing file: ../../segments/LVT_CraP_hhc_5011.wav
# Processing file: ../../segments/LVT_CraP_sd_5012.wav
# Processing file: ../../segments/LVT_IsaP_kd_5013.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5014.wav
# Processing file: ../../segments/LVT_IsaP_kd_5015.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5016.wav
# Processing file: ../../segments/LVT_IsaP_sd_5017.wav
# Processing file: ../../segments/LVT_IsaP_kd_5018.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5019.wav
# Processing file: ../../segments/LVT_IsaP_kd_5020.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5021.wav
# Processing file: ../../segments/LVT_IsaP_sd_5022.wav
# Processing file: ../../segments/LVT_IsaP_kd_5023.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5024.wav
# Processing file: ../../segments/LVT_IsaP_kd_5025.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5026.wav
# Processing file: ../../segments/LVT_IsaP_sd_5027.wav
# Processing file: ../../segments/LVT_IsaP_kd_5028.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5029.wav
# Processing file: ../../segments/LVT_IsaP_kd_5030.wav
# Processing file: ../../segments/LVT_IsaP_hhc_5031.wav
# Processing file: ../../segments/LVT_IsaP_sd_5032.wav
# Processing file: ../../segments/LVT_JOlP_kd_5033.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5034.wav
# Processing file: ../../segments/LVT_JOlP_kd_5035.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5036.wav
# Processing file: ../../segments/LVT_JOlP_sd_5037.wav
# Processing file: ../../segments/LVT_JOlP_kd_5038.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5039.wav
# Processing file: ../../segments/LVT_JOlP_kd_5040.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5041.wav
# Processing file: ../../segments/LVT_JOlP_sd_5042.wav
# Processing file: ../../segments/LVT_JOlP_kd_5043.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5044.wav
# Processing file: ../../segments/LVT_JOlP_kd_5045.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5046.wav
# Processing file: ../../segments/LVT_JOlP_sd_5047.wav
# Processing file: ../../segments/LVT_JOlP_kd_5048.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5049.wav
# Processing file: ../../segments/LVT_JOlP_kd_5050.wav
# Processing file: ../../segments/LVT_JOlP_hhc_5051.wav
# Processing file: ../../segments/LVT_JOlP_sd_5052.wav
# Processing file: ../../segments/LVT_JSiP_kd_5053.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5054.wav
# Processing file: ../../segments/LVT_JSiP_kd_5055.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5056.wav
# Processing file: ../../segments/LVT_JSiP_sd_5057.wav
# Processing file: ../../segments/LVT_JSiP_kd_5058.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5059.wav
# Processing file: ../../segments/LVT_JSiP_kd_5060.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5061.wav
# Processing file: ../../segments/LVT_JSiP_sd_5062.wav
# Processing file: ../../segments/LVT_JSiP_kd_5063.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5064.wav
# Processing file: ../../segments/LVT_JSiP_kd_5065.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5066.wav
# Processing file: ../../segments/LVT_JSiP_sd_5067.wav
# Processing file: ../../segments/LVT_JSiP_kd_5068.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5069.wav
# Processing file: ../../segments/LVT_JSiP_kd_5070.wav
# Processing file: ../../segments/LVT_JSiP_hhc_5071.wav
# Processing file: ../../segments/LVT_JSiP_sd_5072.wav
# Processing file: ../../segments/LVT_JoSP_kd_5073.wav
# Processing file: ../../segments/LVT_JoSP_hhc_5074.wav
# Processing file: ../../segments/LVT_JoSP_kd_5075.wav
# Processing file: ../../segments/LVT_JoSP_hhc_5076.wav
# Processing file: ../../segments/LVT_JoSP_sd_5077.wav
# Processing file: ../../segments/LVT_JoSP_kd_5078.wav
# Processing file: ../../segments/LVT_JoSP_hhc_5079.wav
# Processing file: ../../segments/LVT_JoSP_kd_5080.wav
# Processed 45100 training samples...
# Processing file: ../../segments/LVT_JoSP_hhc_5081.wav
# Processing file: ../../segments/LVT_JoSP_sd_5082.wav
# Processing file: ../../segments/LVT_JoSP_kd_5083.wav
# Processing file: ../../segments/LVT_JoSP_hhc_5084.wav
# Processing file: ../../segments/LVT_JoSP_kd_5085.wav
# Processing file: ../../segments/LVT_JoSP_hhc_5086.wav
# Processing file: ../../segments/LVT_JoSP_sd_5087.wav
# Processing file: ../../segments/LVT_JoSP_kd_5088.wav
# Processing file: ../../segments/LVT_JoSP_hhc_5089.wav
# Processing file: ../../segments/LVT_JoSP_kd_5090.wav
# Processing file: ../../segments/LVT_JoSP_hhc_5091.wav
# Processing file: ../../segments/LVT_JoSP_sd_5092.wav
#
# Processing validation data...
# Processed 0 validation samples...
# Processed 100 validation samples...
# Processed 200 validation samples...
# Processed 300 validation samples...
# Processed 400 validation samples...
# Processed 500 validation samples...
#
# Converting to numpy arrays...
#
# Fold 5 data shapes:
# X_train shape: (45232, 1, 64, 49)
# X_val shape: (512, 1, 64, 49)
#
# Training syllable distribution:
# 0      319
# 1      286
# 2      913
# 3      264
# 4     1298
# 5       22
# 6      407
# 7      594
# 8       11
# 10    1122
# 11    1298
# 13     451
# 14    2717
# 15    3696
# 16     352
# 17     286
# 18    2442
# 19     517
# 20     616
# 21    1254
# 23    1287
# 24    1639
# 25     396
# 26    5181
# 27     297
# 28     418
# 29     429
# 30     792
# 31     407
# 32      88
# 33     858
# 34    6116
# 36     649
# 37     825
# 39    1573
# 40    1056
# 42    2915
# 43     495
# 44     264
# 45     121
# 49      55
# 50     506
# Name: count, dtype: int64
#
# Creating data loaders...
#
# Initializing model...
# Using device: cpu
#
# Training model...
# Epoch 0: train_loss = 205.5672, val_loss = 6.5176
# Epoch 1: train_loss = 35.3290, val_loss = 8.1526
# Epoch 2: train_loss = 16.3532, val_loss = 9.7156
# Epoch 3: train_loss = 11.9040, val_loss = 10.7485
# Epoch 4: train_loss = 10.9677, val_loss = 9.7473
# Epoch 5: train_loss = 7.4988, val_loss = 10.0637
# Epoch 6: train_loss = 5.1806, val_loss = 12.9319
# Epoch 7: train_loss = 1.0722, val_loss = 11.0916
# Epoch 8: train_loss = 0.2006, val_loss = 11.2017
# Epoch 9: train_loss = 0.1328, val_loss = 11.4133
# Epoch 10: train_loss = 0.1060, val_loss = 11.5126
# Early stopping triggered
#
# Generating embeddings...
# Generated embeddings for 0/5714 segments...
# Generated embeddings for 100/5714 segments...
# Generated embeddings for 200/5714 segments...
# Generated embeddings for 300/5714 segments...
# Generated embeddings for 400/5714 segments...
# Generated embeddings for 500/5714 segments...
# Generated embeddings for 600/5714 segments...
# Generated embeddings for 700/5714 segments...
# Generated embeddings for 800/5714 segments...
# Generated embeddings for 900/5714 segments...
# Generated embeddings for 1000/5714 segments...
# Generated embeddings for 1100/5714 segments...
# Generated embeddings for 1200/5714 segments...
# Generated embeddings for 1300/5714 segments...
# Generated embeddings for 1400/5714 segments...
# Generated embeddings for 1500/5714 segments...
# Generated embeddings for 1600/5714 segments...
# Generated embeddings for 1700/5714 segments...
# Generated embeddings for 1800/5714 segments...
# Generated embeddings for 1900/5714 segments...
# Generated embeddings for 2000/5714 segments...
# Generated embeddings for 2100/5714 segments...
# Generated embeddings for 2200/5714 segments...
# Generated embeddings for 2300/5714 segments...
# Generated embeddings for 2400/5714 segments...
# Generated embeddings for 2500/5714 segments...
# Generated embeddings for 2600/5714 segments...
# Generated embeddings for 2700/5714 segments...
# Generated embeddings for 2800/5714 segments...
# Generated embeddings for 2900/5714 segments...
# Generated embeddings for 3000/5714 segments...
# Generated embeddings for 3100/5714 segments...
# Generated embeddings for 3200/5714 segments...
# Generated embeddings for 3300/5714 segments...
# Generated embeddings for 3400/5714 segments...
# Generated embeddings for 3500/5714 segments...
# Generated embeddings for 3600/5714 segments...
# Generated embeddings for 3700/5714 segments...
# Generated embeddings for 3800/5714 segments...
# Generated embeddings for 3900/5714 segments...
# Generated embeddings for 4000/5714 segments...
# Generated embeddings for 4100/5714 segments...
# Generated embeddings for 4200/5714 segments...
# Generated embeddings for 4300/5714 segments...
# Generated embeddings for 4400/5714 segments...
# Generated embeddings for 4500/5714 segments...
# Generated embeddings for 4600/5714 segments...
# Generated embeddings for 4700/5714 segments...
# Generated embeddings for 4800/5714 segments...
# Generated embeddings for 4900/5714 segments...
# Generated embeddings for 5000/5714 segments...
# Generated embeddings for 5100/5714 segments...
# Generated embeddings for 5200/5714 segments...
# Generated embeddings for 5300/5714 segments...
# Generated embeddings for 5400/5714 segments...
# Generated embeddings for 5500/5714 segments...
# Generated embeddings for 5600/5714 segments...
# Generated embeddings for 5700/5714 segments...
#
# Saving embeddings...
# Done!
